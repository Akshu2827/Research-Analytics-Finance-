# %%
"""
Quantitative Analysis of Maritime Defense Companies Around Chokepoint Disruptions
with Additional Financial Health Metrics (Sharpe, Volatility, M-Score, Z-Score, Outliers)
and Event-Wise CAR Correlation Matrices (Heatmaps Only - No Line Plots)
"""

import pandas as pd
import numpy as np
import yfinance as yf
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import timedelta
from scipy import stats

# ==========================
# 1. Configuration
# ==========================

COMPANIES = {
    "Lockheed Martin": "LMT",
    "Raytheon Technologies": "RTX",
    "General Dynamics": "GD",
    "Northrop Grumman": "NOC",
    "BAE Systems": "BA.L",
    "Rolls-Royce Holdings": "RR.L",
    "Thales Group (UK Div)": "HO.PA",
    "Mitsubishi Heavy Ind": "7011.T",
    "Kawasaki Heavy Ind": "7012.T",
    "Mitsubishi Electric": "6503.T",
    "Garden Reach Shipbuilders": "GRSE.NS",
    "Mazagon Dock Shipbuilders": "MAZDOCK.NS",
    "Cochin Shipyard": "COCHINSHIP.NS",
}

BENCHMARKS = {
    "US": "^GSPC",
    "UK": "^FTSE",
    "Japan": "^N225",
    "India": "^NSEI",
}

def get_benchmark_for_company(company_ticker):
    if company_ticker in ["LMT", "RTX", "GD", "NOC"]:
        return BENCHMARKS["US"]
    elif company_ticker in ["BA.L", "RR.L", "HO.PA"]:
        return BENCHMARKS["UK"]
    elif company_ticker in ["7011.T", "7012.T", "6503.T"]:
        return BENCHMARKS["Japan"]
    elif company_ticker in ["GRSE.NS", "MAZDOCK.NS", "COCHINSHIP.NS"]:
        return BENCHMARKS["India"]
    else:
        raise ValueError(f"Unknown region for ticker {company_ticker}")

EVENTS = {
    "Strait of Hormuz Blockade (hypothetical)": "2026-04-12",
    "Red Sea Houthi attacks (start)": "2023-12-01",
    "Suez Canal blocked (Ever Given)": "2021-03-23",
    "Hormuz tanker attacks (escalation)": "2019-05-01",
    "Maersk Tigris seizure": "2015-04-28",
    "Tanker War (Iran-Iraq) peak": "1987-08-01",
    "Six-Day War / Suez closure": "1967-06-05",
}

WINDOW_DAYS = 30

# ==========================
# 2. Event study functions
# ==========================

def fetch_data(tickers, start_date, end_date):
    print(f"Downloading data from {start_date} to {end_date} ...")
    data = yf.download(tickers, start=start_date, end=end_date, group_by='ticker', auto_adjust=True)
    if len(tickers) == 1:
        data = pd.DataFrame({tickers[0]: data['Close']})
    else:
        close_data = {}
        for t in tickers:
            if t in data.columns.levels[0]:
                close_data[t] = data[t]['Close']
            else:
                print(f"Warning: {t} not found. Skipping.")
        data = pd.DataFrame(close_data)
    return data

def compute_abnormal_returns(company_returns, benchmark_returns):
    return company_returns - benchmark_returns

def cumulative_abnormal_returns(abnormal_returns, event_date, window_days):
    start = event_date - timedelta(days=window_days)
    end = event_date + timedelta(days=window_days)
    ar_window = abnormal_returns.loc[start:end]
    car = ar_window.cumsum()
    car.index = (car.index - event_date).days
    return car

def run_event_study_for_company(company_name, ticker, event_dates, window_days):
    print(f"\n--- Processing {company_name} ({ticker}) ---")
    benchmark_ticker = get_benchmark_for_company(ticker)
    all_event_dates = [pd.to_datetime(d) for d in event_dates.values()]
    min_date = min(all_event_dates) - timedelta(days=window_days+10)
    max_date = max(all_event_dates) + timedelta(days=window_days+10)
    data = fetch_data([ticker, benchmark_ticker], min_date.strftime("%Y-%m-%d"), max_date.strftime("%Y-%m-%d"))
    if ticker not in data.columns or benchmark_ticker not in data.columns:
        print(f"Missing data for {ticker} or {benchmark_ticker}. Skipping.")
        return None, None
    company_returns = data[ticker].pct_change().dropna()
    benchmark_returns = data[benchmark_ticker].pct_change().dropna()
    common_idx = company_returns.index.intersection(benchmark_returns.index)
    company_returns = company_returns[common_idx]
    benchmark_returns = benchmark_returns[common_idx]
    abnormal_ret = compute_abnormal_returns(company_returns, benchmark_returns)
    car_results = {}
    for event_name, event_date_str in event_dates.items():
        event_date = pd.to_datetime(event_date_str)
        if event_date < common_idx.min() or event_date > common_idx.max():
            print(f"Event '{event_name}' on {event_date_str} outside data range. Skipping.")
            continue
        car = cumulative_abnormal_returns(abnormal_ret, event_date, window_days)
        car_results[event_name] = car
    if car_results:
        car_df = pd.DataFrame(car_results)
        car_df.index.name = "Days from event"
        return car_df, company_returns
    else:
        return None, company_returns

# ==========================
# 3. Sharpe ratio & volatility
# ==========================

def compute_sharpe_volatility(returns, risk_free_rate=0.02):
    if len(returns) < 2:
        return np.nan, np.nan
    daily_rf = (1 + risk_free_rate) ** (1/252) - 1
    excess_returns = returns - daily_rf
    sharpe_daily = excess_returns.mean() / excess_returns.std() if excess_returns.std() != 0 else np.nan
    sharpe_annual = sharpe_daily * np.sqrt(252)
    vol_annual = returns.std() * np.sqrt(252)
    return sharpe_annual, vol_annual

# ==========================
# 4. Beneish M-Score
# ==========================

def compute_beneish_m_score(ticker):
    try:
        stock = yf.Ticker(ticker)
        bs = stock.balance_sheet
        is_ = stock.financials
        if bs.empty or is_.empty:
            return np.nan, np.nan
        bs = bs.iloc[:, 0]
        is_ = is_.iloc[:, 0]
        
        def get_value(df, possible_names):
            for name in possible_names:
                if name in df.index:
                    return df[name]
            return np.nan
        
        receivables = get_value(bs, ['Net Receivables', 'Accounts Receivable', 'Trade Receivables'])
        sales = get_value(is_, ['Total Revenue', 'Revenue'])
        dsri = 1.0  # placeholder
        
        cogs = get_value(is_, ['Cost Of Revenue', 'Cost of Goods Sold'])
        if pd.notna(sales) and pd.notna(cogs):
            gross_margin = (sales - cogs) / sales
            gmi = 1.0 / gross_margin if gross_margin > 0 else 1.0
        else:
            gmi = 1.0
        
        total_assets = get_value(bs, ['Total Assets'])
        current_assets = get_value(bs, ['Total Current Assets'])
        if pd.notna(total_assets) and pd.notna(current_assets):
            non_current_assets = total_assets - current_assets
            aqi = non_current_assets / total_assets
        else:
            aqi = 1.0
        
        sgi = 1.0
        depi = 1.0
        sgai = 1.0
        
        total_liab = get_value(bs, ['Total Liabilities Net Minority Interest', 'Total Liabilities'])
        if pd.notna(total_assets) and pd.notna(total_liab):
            leverage = total_liab / total_assets
            lvgi = leverage
        else:
            lvgi = 1.0
        
        net_income = get_value(is_, ['Net Income', 'Net Income Common Stockholders'])
        cash_from_ops = get_value(is_, ['Operating Cash Flow'])
        if pd.notna(net_income) and pd.notna(cash_from_ops) and pd.notna(total_assets):
            tata = (net_income - cash_from_ops) / total_assets
        else:
            tata = 0.0
        
        m_score = (-4.84) + 0.92*dsri + 0.528*gmi + 0.404*aqi + 0.892*sgi + 0.115*depi - 0.172*sgai + 4.679*tata - 0.327*lvgi
        prob = 1 / (1 + np.exp(-m_score))
        return m_score, prob
    except Exception as e:
        print(f"Error computing M-Score for {ticker}: {e}")
        return np.nan, np.nan

# ==========================
# 5. Altman Z-Score
# ==========================

def compute_altman_z_score(ticker, is_emerging_market=False):
    try:
        stock = yf.Ticker(ticker)
        bs = stock.balance_sheet
        is_ = stock.financials
        if bs.empty or is_.empty:
            return np.nan
        bs = bs.iloc[:, 0]
        is_ = is_.iloc[:, 0]
        
        def get_value(df, possible_names):
            for name in possible_names:
                if name in df.index:
                    return df[name]
            return np.nan
        
        current_assets = get_value(bs, ['Total Current Assets', 'Current Assets'])
        current_liab = get_value(bs, ['Total Current Liabilities', 'Current Liabilities'])
        working_capital = (current_assets - current_liab) if pd.notna(current_assets) and pd.notna(current_liab) else np.nan
        total_assets = get_value(bs, ['Total Assets'])
        retained_earnings = get_value(bs, ['Retained Earnings'])
        ebit = get_value(is_, ['EBIT', 'Operating Income'])
        
        market_cap = stock.info.get('marketCap', np.nan)
        if pd.isna(market_cap) and ticker.endswith('.NS'):
            shares = stock.info.get('sharesOutstanding', np.nan)
            price = stock.info.get('regularMarketPrice', np.nan)
            if pd.notna(shares) and pd.notna(price):
                market_cap = shares * price
        
        total_liab = get_value(bs, ['Total Liabilities Net Minority Interest', 'Total Liabilities'])
        sales = get_value(is_, ['Total Revenue', 'Revenue'])
        
        X1 = working_capital / total_assets if pd.notna(working_capital) and pd.notna(total_assets) and total_assets != 0 else np.nan
        X2 = retained_earnings / total_assets if pd.notna(retained_earnings) and pd.notna(total_assets) and total_assets != 0 else np.nan
        X3 = ebit / total_assets if pd.notna(ebit) and pd.notna(total_assets) and total_assets != 0 else np.nan
        X4 = market_cap / total_liab if pd.notna(market_cap) and pd.notna(total_liab) and total_liab != 0 else np.nan
        X5 = sales / total_assets if pd.notna(sales) and pd.notna(total_assets) and total_assets != 0 else np.nan
        
        if is_emerging_market:
            book_equity = get_value(bs, ['Total Equity Gross Minority Interest', 'Stockholders Equity'])
            X4_prime = book_equity / total_liab if pd.notna(book_equity) and pd.notna(total_liab) and total_liab != 0 else np.nan
            z_score = 6.56 * X1 + 3.26 * X2 + 6.72 * X3 + 1.05 * X4_prime
        else:
            z_score = 1.2 * X1 + 1.4 * X2 + 3.3 * X3 + 0.6 * X4 + 1.0 * X5
        return z_score
    except Exception as e:
        print(f"Error computing Z-Score for {ticker}: {e}")
        return np.nan

# ==========================
# 6. Outlier detection
# ==========================

def get_financial_ratios(ticker):
    try:
        stock = yf.Ticker(ticker)
        bs = stock.balance_sheet
        is_ = stock.financials
        if bs.empty or is_.empty:
            return {}
        bs = bs.iloc[:, 0]
        is_ = is_.iloc[:, 0]
        
        def get_value(df, possible_names):
            for name in possible_names:
                if name in df.index:
                    return df[name]
            return np.nan
        
        total_assets = get_value(bs, ['Total Assets'])
        total_liab = get_value(bs, ['Total Liabilities Net Minority Interest', 'Total Liabilities'])
        equity = get_value(bs, ['Total Equity Gross Minority Interest', 'Stockholders Equity'])
        revenue = get_value(is_, ['Total Revenue', 'Revenue'])
        net_income = get_value(is_, ['Net Income', 'Net Income Common Stockholders'])
        current_assets = get_value(bs, ['Total Current Assets', 'Current Assets'])
        current_liab = get_value(bs, ['Total Current Liabilities', 'Current Liabilities'])
        
        ratios = {}
        if pd.notna(current_assets) and pd.notna(current_liab) and current_liab != 0:
            ratios['Current Ratio'] = current_assets / current_liab
        if pd.notna(total_liab) and pd.notna(equity) and equity != 0:
            ratios['Debt/Equity'] = total_liab / equity
        if pd.notna(net_income) and pd.notna(equity) and equity != 0:
            ratios['ROE'] = net_income / equity
        if pd.notna(net_income) and pd.notna(revenue) and revenue != 0:
            ratios['Net Margin'] = net_income / revenue
        if pd.notna(total_liab) and pd.notna(total_assets) and total_assets != 0:
            ratios['Debt/Assets'] = total_liab / total_assets
        return ratios
    except Exception as e:
        print(f"Error computing ratios for {ticker}: {e}")
        return {}

def detect_outliers(all_ratios_dict):
    outliers = {}
    if not all_ratios_dict:
        return outliers
    ratio_names = set()
    for ratios in all_ratios_dict.values():
        ratio_names.update(ratios.keys())
    for ratio in ratio_names:
        values = []
        companies = []
        for comp, rat in all_ratios_dict.items():
            if ratio in rat and pd.notna(rat[ratio]):
                values.append(rat[ratio])
                companies.append(comp)
        if len(values) < 2:
            continue
        z_scores = stats.zscore(values)
        for comp, z in zip(companies, z_scores):
            if abs(z) > 3:
                if comp not in outliers:
                    outliers[comp] = []
                outliers[comp].append((ratio, z))
    return outliers

# ==========================
# 7. Correlation helper (no line plots)
# ==========================

def compute_event_correlations(all_car):
    """
    all_car: dict {company_name: DataFrame with columns = events, index = day offsets}
    For each event, collect CAR series for all companies and compute pairwise correlations.
    Returns dict event_name -> correlation DataFrame.
    """
    event_to_companies = {}
    for company, car_df in all_car.items():
        for event_name in car_df.columns:
            if event_name not in event_to_companies:
                event_to_companies[event_name] = {}
            event_to_companies[event_name][company] = car_df[event_name]
    
    correlations = {}
    for event_name, company_series_dict in event_to_companies.items():
        common_index = None
        for ser in company_series_dict.values():
            if common_index is None:
                common_index = ser.index
            else:
                common_index = common_index.intersection(ser.index)
        if len(common_index) < 2:
            print(f"Event {event_name}: Not enough days to compute correlation.")
            continue
        df = pd.DataFrame({company: ser.loc[common_index] for company, ser in company_series_dict.items()})
        corr_mat = df.corr()
        correlations[event_name] = corr_mat
    return correlations

# ==========================
# 8. Main execution (no line plots)
# ==========================

if __name__ == "__main__":
    sns.set_style("whitegrid")
    
    all_car = {}
    all_returns = {}
    for company_name, ticker in COMPANIES.items():
        car_df, ret_series = run_event_study_for_company(company_name, ticker, EVENTS, WINDOW_DAYS)
        if car_df is not None:
            all_car[company_name] = car_df
        if ret_series is not None and len(ret_series) > 0:
            all_returns[company_name] = ret_series
    
    if not all_car:
        print("No valid CAR data generated. Exiting.")
        exit()
    
    # Sharpe & Volatility
    sharpe_vol = {}
    for company_name, returns in all_returns.items():
        sharpe, vol = compute_sharpe_volatility(returns)
        sharpe_vol[company_name] = (sharpe, vol)
    
    # Beneish & Altman
    beneish_results = {}
    altman_results = {}
    for company_name, ticker in COMPANIES.items():
        m_score, prob = compute_beneish_m_score(ticker)
        beneish_results[company_name] = (m_score, prob)
        is_india = ticker.endswith('.NS')
        z = compute_altman_z_score(ticker, is_emerging_market=is_india)
        altman_results[company_name] = z
    
    # Outliers
    all_ratios = {}
    for company_name, ticker in COMPANIES.items():
        ratios = get_financial_ratios(ticker)
        all_ratios[company_name] = ratios
    outlier_flags = detect_outliers(all_ratios)
    
    # Print summary
    print("\n" + "="*80)
    print("COMPREHENSIVE FINANCIAL & EVENT STUDY SUMMARY")
    print("="*80)
    print(f"\n{'Company':<35} {'Sharpe':>8} {'Volatility':>10} {'M-Score':>10} {'Prob. Manip':>12} {'Altman Z':>10}")
    print("-"*90)
    for company_name in COMPANIES.keys():
        sharpe, vol = sharpe_vol.get(company_name, (np.nan, np.nan))
        m_score, prob = beneish_results.get(company_name, (np.nan, np.nan))
        z = altman_results.get(company_name, np.nan)
        print(f"{company_name:<35} {sharpe:>8.2f} {vol:>10.2%} {m_score:>10.2f} {prob:>12.2f} {z:>10.2f}")
    
    print("\n" + "-"*80)
    print("FINANCIAL RATIO OUTLIERS (|z-score| > 3)")
    if outlier_flags:
        for company, flags in outlier_flags.items():
            print(f"\n{company}:")
            for ratio, z in flags:
                print(f"  - {ratio}: z = {z:.2f}")
    else:
        print("No extreme outliers detected.")
    
    # Event study CAR max/min (per company per event)
    print("\n" + "-"*80)
    print("EVENT STUDY CUMULATIVE ABNORMAL RETURNS (CAR) – BREAKDOWN BY EVENT")
    for company_name, car_df in all_car.items():
        print(f"\n{company_name}:")
        for event_name in car_df.columns:
            max_car = car_df[event_name].max()
            min_car = car_df[event_name].min()
            print(f"  {event_name}: max CAR = {max_car:.2%}, min CAR = {min_car:.2%}")
    
    # Correlation heatmaps for each event (no line plots)
    print("\n" + "-"*80)
    print("EVENT-WISE CORRELATION MATRICES (HEATMAPS)")
    event_corrs = compute_event_correlations(all_car)
    for event_name, corr_mat in event_corrs.items():
        print(f"\nEvent: {event_name}")
        print(corr_mat.round(2))
        plt.figure(figsize=(8, 6))
        sns.heatmap(corr_mat, annot=True, cmap='coolwarm', center=0, fmt='.2f')
        plt.title(f"CAR Correlation Matrix - {event_name}")
        plt.tight_layout()
        plt.show()
    
    print("\n" + "="*80)
    print("INTERPRETATION NOTES:")
    print("  - Sharpe ratio > 1 is good; volatility is annualized standard deviation of daily returns.")
    print("  - Beneish M-Score < -2.22 suggests no manipulation; > -2.22 suggests possible manipulation.")
    print("  - Altman Z-Score: > 2.99 safe, 1.81-2.99 grey, < 1.81 distress zone (original).")
    print("  - For emerging markets Z'' > 2.60 safe, 1.10-2.60 grey, < 1.10 distress.")
    print("  - Outliers flagged by z-score > 3 indicate ratios unusually far from the group mean.")
    print("  - Correlation heatmaps show how similarly companies' abnormal returns moved around each event.")


# =============================================================================
# EXTENSION: LINEAR (TIME SERIES) PLOTS OF CUMULATIVE ABNORMAL RETURNS PER EVENT
# =============================================================================
# Uncomment the code below if you want to generate the line plots for each event.
# This extension uses the `all_car` dictionary created in the main execution.

def plot_car_time_series_for_events(all_car):
    """
    For each event, create a single figure showing the CAR time series
    of all companies that have data for that event.
    """
    # Collect all event names
    all_event_names = set()
    for car_df in all_car.values():
        all_event_names.update(car_df.columns)
    
    for event_name in all_event_names:
        plt.figure(figsize=(12, 6))
        for company_name, car_df in all_car.items():
            if event_name in car_df.columns:
                plt.plot(car_df.index, car_df[event_name], label=company_name, linewidth=1.5)
        plt.axhline(0, color='black', linestyle='--', linewidth=0.8)
        plt.axvline(0, color='red', linestyle='--', label='Event day')
        plt.title(f"Cumulative Abnormal Returns - {event_name}")
        plt.xlabel("Trading days relative to event")
        plt.ylabel("CAR")
        plt.legend(bbox_to_anchor=(1.05, 1), loc='upper left', fontsize=8)
        plt.grid(True, alpha=0.3)
        plt.tight_layout()
        plt.show()

# Call the extension (uncomment the next line to activate)
plot_car_time_series_for_events(all_car)
# Out:
# --- Processing Lockheed Martin (LMT) ---
# Downloading data from 1967-04-26 to 2026-05-22 ...
# [*********************100%***********************]  2 of 2 completed
# --- Processing Raytheon Technologies (RTX) ---
# Downloading data from 1967-04-26 to 2026-05-22 ...
# [*********************100%***********************]  2 of 2 completed
# --- Processing General Dynamics (GD) ---
# Downloading data from 1967-04-26 to 2026-05-22 ...
# [*********************100%***********************]  2 of 2 completed
# --- Processing Northrop Grumman (NOC) ---
# Downloading data from 1967-04-26 to 2026-05-22 ...
# [*********************100%***********************]  2 of 2 completed
# Event 'Six-Day War / Suez closure' on 1967-06-05 outside data range. Skipping.
#
# --- Processing BAE Systems (BA.L) ---
# Downloading data from 1967-04-26 to 2026-05-22 ...
# [*********************100%***********************]  2 of 2 completed
# Event 'Tanker War (Iran-Iraq) peak' on 1987-08-01 outside data range. Skipping.
# Event 'Six-Day War / Suez closure' on 1967-06-05 outside data range. Skipping.
#
# --- Processing Rolls-Royce Holdings (RR.L) ---
# Downloading data from 1967-04-26 to 2026-05-22 ...
# [*********************100%***********************]  2 of 2 completed
# [                       0%                       ]
# Event 'Tanker War (Iran-Iraq) peak' on 1987-08-01 outside data range. Skipping.
# Event 'Six-Day War / Suez closure' on 1967-06-05 outside data range. Skipping.
#
# --- Processing Thales Group (UK Div) (HO.PA) ---
# Downloading data from 1967-04-26 to 2026-05-22 ...
# [*********************100%***********************]  2 of 2 completed
# Event 'Tanker War (Iran-Iraq) peak' on 1987-08-01 outside data range. Skipping.
# Event 'Six-Day War / Suez closure' on 1967-06-05 outside data range. Skipping.
#
# --- Processing Mitsubishi Heavy Ind (7011.T) ---
# Downloading data from 1967-04-26 to 2026-05-22 ...
# [*********************100%***********************]  2 of 2 completed
# [                       0%                       ]
# Event 'Tanker War (Iran-Iraq) peak' on 1987-08-01 outside data range. Skipping.
# Event 'Six-Day War / Suez closure' on 1967-06-05 outside data range. Skipping.
#
# --- Processing Kawasaki Heavy Ind (7012.T) ---
# Downloading data from 1967-04-26 to 2026-05-22 ...
# [*********************100%***********************]  2 of 2 completed
# Event 'Tanker War (Iran-Iraq) peak' on 1987-08-01 outside data range. Skipping.
# Event 'Six-Day War / Suez closure' on 1967-06-05 outside data range. Skipping.
#
# --- Processing Mitsubishi Electric (6503.T) ---
# Downloading data from 1967-04-26 to 2026-05-22 ...
# [*********************100%***********************]  2 of 2 completed
# Event 'Tanker War (Iran-Iraq) peak' on 1987-08-01 outside data range. Skipping.
# Event 'Six-Day War / Suez closure' on 1967-06-05 outside data range. Skipping.
#
# --- Processing Garden Reach Shipbuilders (GRSE.NS) ---
# Downloading data from 1967-04-26 to 2026-05-22 ...
# [*********************100%***********************]  2 of 2 completed
# Event 'Maersk Tigris seizure' on 2015-04-28 outside data range. Skipping.
# Event 'Tanker War (Iran-Iraq) peak' on 1987-08-01 outside data range. Skipping.
# Event 'Six-Day War / Suez closure' on 1967-06-05 outside data range. Skipping.
#
# --- Processing Mazagon Dock Shipbuilders (MAZDOCK.NS) ---
# Downloading data from 1967-04-26 to 2026-05-22 ...
# [*********************100%***********************]  2 of 2 completed
# Event 'Hormuz tanker attacks (escalation)' on 2019-05-01 outside data range. Skipping.
# Event 'Maersk Tigris seizure' on 2015-04-28 outside data range. Skipping.
# Event 'Tanker War (Iran-Iraq) peak' on 1987-08-01 outside data range. Skipping.
# Event 'Six-Day War / Suez closure' on 1967-06-05 outside data range. Skipping.
#
# --- Processing Cochin Shipyard (COCHINSHIP.NS) ---
# Downloading data from 1967-04-26 to 2026-05-22 ...
# [*********************100%***********************]  2 of 2 completed
# Event 'Maersk Tigris seizure' on 2015-04-28 outside data range. Skipping.
# Event 'Tanker War (Iran-Iraq) peak' on 1987-08-01 outside data range. Skipping.
# Event 'Six-Day War / Suez closure' on 1967-06-05 outside data range. Skipping.
#
# ================================================================================
# COMPREHENSIVE FINANCIAL & EVENT STUDY SUMMARY
# ================================================================================
#
# Company                               Sharpe Volatility    M-Score  Prob. Manip   Altman Z
# ------------------------------------------------------------------------------------------
# Lockheed Martin                         0.38     35.34%       2.23         0.90       3.39
# Raytheon Technologies                   0.45     27.81%      -0.25         0.44       2.59
# General Dynamics                        0.47     29.67%       0.63         0.65       4.25
# Northrop Grumman                        0.51     27.38%      -0.24         0.44       3.06
# BAE Systems                             0.19    244.61%      -2.09         0.11       2.57
# Rolls-Royce Holdings                    0.35     38.18%      -1.17         0.24       3.21
# Thales Group (UK Div)                   0.40     29.13%      -0.94         0.28       1.77
# Mitsubishi Heavy Ind                    0.39     35.81%      -2.36         0.09        nan
# Kawasaki Heavy Ind                      0.45     41.61%      -2.40         0.08        nan
# Mitsubishi Electric                     0.35     37.19%      -1.08         0.25       5.69
# Garden Reach Shipbuilders               1.14     54.00%      -0.39         0.40       2.20
# Mazagon Dock Shipbuilders               1.47     50.92%      -1.41         0.20        nan
# Cochin Shipyard                         0.71     42.28%      -0.58         0.36        nan
#
# --------------------------------------------------------------------------------
# FINANCIAL RATIO OUTLIERS (|z-score| > 3)
#
# Rolls-Royce Holdings:
#   - ROE: z = 3.01
#
# --------------------------------------------------------------------------------
# EVENT STUDY CUMULATIVE ABNORMAL RETURNS (CAR) – BREAKDOWN BY EVENT
#
# Lockheed Martin:
#   Strait of Hormuz Blockade (hypothetical): max CAR = -0.44%, min CAR = -35.35%
#   Red Sea Houthi attacks (start): max CAR = -1.55%, min CAR = -13.96%
#   Suez Canal blocked (Ever Given): max CAR = 10.13%, min CAR = 0.31%
#   Hormuz tanker attacks (escalation): max CAR = 15.86%, min CAR = -2.31%
#   Maersk Tigris seizure: max CAR = 0.09%, min CAR = -9.15%
#   Tanker War (Iran-Iraq) peak: max CAR = 10.78%, min CAR = -1.82%
#   Six-Day War / Suez closure: max CAR = 11.76%, min CAR = -3.94%
#
# Raytheon Technologies:
#   Strait of Hormuz Blockade (hypothetical): max CAR = 1.47%, min CAR = -24.28%
#   Red Sea Houthi attacks (start): max CAR = -0.12%, min CAR = -12.35%
#   Suez Canal blocked (Ever Given): max CAR = 6.23%, min CAR = -0.93%
#   Hormuz tanker attacks (escalation): max CAR = 6.41%, min CAR = 0.31%
#   Maersk Tigris seizure: max CAR = 0.43%, min CAR = -3.86%
#   Tanker War (Iran-Iraq) peak: max CAR = 3.69%, min CAR = -2.66%
#   Six-Day War / Suez closure: max CAR = 18.31%, min CAR = -2.37%
#
# General Dynamics:
#   Strait of Hormuz Blockade (hypothetical): max CAR = 2.98%, min CAR = -19.53%
#   Red Sea Houthi attacks (start): max CAR = -0.47%, min CAR = -8.00%
#   Suez Canal blocked (Ever Given): max CAR = 9.09%, min CAR = 1.48%
#   Hormuz tanker attacks (escalation): max CAR = 4.77%, min CAR = -2.25%
#   Maersk Tigris seizure: max CAR = 2.83%, min CAR = -3.60%
#   Tanker War (Iran-Iraq) peak: max CAR = 3.68%, min CAR = -3.21%
#   Six-Day War / Suez closure: max CAR = 31.74%, min CAR = 0.49%
#
# Northrop Grumman:
#   Strait of Hormuz Blockade (hypothetical): max CAR = 0.25%, min CAR = -39.59%
#   Red Sea Houthi attacks (start): max CAR = -1.72%, min CAR = -14.51%
#   Suez Canal blocked (Ever Given): max CAR = 9.82%, min CAR = -0.69%
#   Hormuz tanker attacks (escalation): max CAR = 15.94%, min CAR = -2.39%
#   Maersk Tigris seizure: max CAR = 1.30%, min CAR = -5.86%
#   Tanker War (Iran-Iraq) peak: max CAR = 11.87%, min CAR = -2.66%
#
# BAE Systems:
#   Strait of Hormuz Blockade (hypothetical): max CAR = 2.78%, min CAR = -16.72%
#   Red Sea Houthi attacks (start): max CAR = 0.94%, min CAR = -10.47%
#   Suez Canal blocked (Ever Given): max CAR = 8.77%, min CAR = 1.58%
#   Hormuz tanker attacks (escalation): max CAR = 3.24%, min CAR = -7.26%
#   Maersk Tigris seizure: max CAR = -0.04%, min CAR = -7.94%
#
# Rolls-Royce Holdings:
#   Strait of Hormuz Blockade (hypothetical): max CAR = 2.45%, min CAR = -12.66%
#   Red Sea Houthi attacks (start): max CAR = 32.28%, min CAR = 1.25%
#   Suez Canal blocked (Ever Given): max CAR = 24.44%, min CAR = -0.87%
#   Hormuz tanker attacks (escalation): max CAR = 3.86%, min CAR = -4.41%
#   Maersk Tigris seizure: max CAR = 8.53%, min CAR = -2.06%
#
# Thales Group (UK Div):
#   Strait of Hormuz Blockade (hypothetical): max CAR = 4.17%, min CAR = -13.97%
#   Red Sea Houthi attacks (start): max CAR = 0.01%, min CAR = -8.50%
#   Suez Canal blocked (Ever Given): max CAR = 11.47%, min CAR = 1.95%
#   Hormuz tanker attacks (escalation): max CAR = 2.98%, min CAR = -5.36%
#   Maersk Tigris seizure: max CAR = 8.85%, min CAR = -0.53%
#
# Mitsubishi Heavy Ind:
#   Strait of Hormuz Blockade (hypothetical): max CAR = 3.75%, min CAR = -23.80%
#   Red Sea Houthi attacks (start): max CAR = 5.86%, min CAR = -6.96%
#   Suez Canal blocked (Ever Given): max CAR = 19.44%, min CAR = -0.30%
#   Hormuz tanker attacks (escalation): max CAR = 6.59%, min CAR = -5.81%
#   Maersk Tigris seizure: max CAR = 11.81%, min CAR = -4.30%
#
# Kawasaki Heavy Ind:
#   Strait of Hormuz Blockade (hypothetical): max CAR = 0.78%, min CAR = -17.44%
#   Red Sea Houthi attacks (start): max CAR = -0.11%, min CAR = -20.27%
#   Suez Canal blocked (Ever Given): max CAR = 24.48%, min CAR = 0.11%
#   Hormuz tanker attacks (escalation): max CAR = 2.53%, min CAR = -11.35%
#   Maersk Tigris seizure: max CAR = 0.69%, min CAR = -4.17%
#
# Mitsubishi Electric:
#   Strait of Hormuz Blockade (hypothetical): max CAR = 4.84%, min CAR = -3.32%
#   Red Sea Houthi attacks (start): max CAR = 15.13%, min CAR = 7.97%
#   Suez Canal blocked (Ever Given): max CAR = 11.06%, min CAR = -0.55%
#   Hormuz tanker attacks (escalation): max CAR = 6.01%, min CAR = -2.88%
#   Maersk Tigris seizure: max CAR = 11.49%, min CAR = -0.30%
#
# Garden Reach Shipbuilders:
#   Strait of Hormuz Blockade (hypothetical): max CAR = 30.63%, min CAR = -14.40%
#   Red Sea Houthi attacks (start): max CAR = 8.09%, min CAR = -1.66%
#   Suez Canal blocked (Ever Given): max CAR = 6.82%, min CAR = -8.03%
#   Hormuz tanker attacks (escalation): max CAR = 22.61%, min CAR = -3.13%
#
# Mazagon Dock Shipbuilders:
#   Strait of Hormuz Blockade (hypothetical): max CAR = 12.80%, min CAR = -10.68%
#   Red Sea Houthi attacks (start): max CAR = 6.40%, min CAR = -6.28%
#   Suez Canal blocked (Ever Given): max CAR = 8.48%, min CAR = -5.42%
#
# Cochin Shipyard:
#   Strait of Hormuz Blockade (hypothetical): max CAR = 23.04%, min CAR = -12.86%
#   Red Sea Houthi attacks (start): max CAR = 27.40%, min CAR = -1.45%
#   Suez Canal blocked (Ever Given): max CAR = 14.18%, min CAR = -0.73%
#   Hormuz tanker attacks (escalation): max CAR = 0.73%, min CAR = -10.02%
#
# --------------------------------------------------------------------------------
# EVENT-WISE CORRELATION MATRICES (HEATMAPS)
#
# Event: Strait of Hormuz Blockade (hypothetical)
#                            Lockheed Martin  Raytheon Technologies  \
# Lockheed Martin                       1.00                   0.99
# Raytheon Technologies                 0.99                   1.00
# General Dynamics                      0.85                   0.83
# Northrop Grumman                      0.99                   0.99
# BAE Systems                           0.91                   0.91
# Rolls-Royce Holdings                  0.01                   0.09
# Thales Group (UK Div)                 0.83                   0.84
# Mitsubishi Heavy Ind                  0.86                   0.85
# Kawasaki Heavy Ind                    0.84                   0.87
# Mitsubishi Electric                  -0.53                  -0.48
# Garden Reach Shipbuilders            -0.95                  -0.92
# Mazagon Dock Shipbuilders            -0.93                  -0.91
# Cochin Shipyard                      -0.97                  -0.95
#
#                            General Dynamics  Northrop Grumman  BAE Systems  \
# Lockheed Martin                        0.85              0.99         0.91
# Raytheon Technologies                  0.83              0.99         0.91
# General Dynamics                       1.00              0.84         0.77
# Northrop Grumman                       0.84              1.00         0.93
# BAE Systems                            0.77              0.93         1.00
# Rolls-Royce Holdings                   0.09             -0.01         0.10
# Thales Group (UK Div)                  0.58              0.83         0.83
# Mitsubishi Heavy Ind                   0.76              0.89         0.86
# Kawasaki Heavy Ind                     0.77              0.85         0.83
# Mitsubishi Electric                   -0.38             -0.54        -0.45
# Garden Reach Shipbuilders             -0.81             -0.95        -0.81
# Mazagon Dock Shipbuilders             -0.85             -0.92        -0.75
# Cochin Shipyard                       -0.80             -0.95        -0.83
#
#                            Rolls-Royce Holdings  Thales Group (UK Div)  \
# Lockheed Martin                            0.01                   0.83
# Raytheon Technologies                      0.09                   0.84
# General Dynamics                           0.09                   0.58
# Northrop Grumman                          -0.01                   0.83
# BAE Systems                                0.10                   0.83
# Rolls-Royce Holdings                       1.00                   0.15
# Thales Group (UK Div)                      0.15                   1.00
# Mitsubishi Heavy Ind                      -0.18                   0.66
# Kawasaki Heavy Ind                         0.14                   0.68
# Mitsubishi Electric                        0.36                  -0.40
# Garden Reach Shipbuilders                  0.19                  -0.71
# Mazagon Dock Shipbuilders                  0.12                  -0.67
# Cochin Shipyard                            0.11                  -0.78
#
#                            Mitsubishi Heavy Ind  Kawasaki Heavy Ind  \
# Lockheed Martin                            0.86                0.84
# Raytheon Technologies                      0.85                0.87
# General Dynamics                           0.76                0.77
# Northrop Grumman                           0.89                0.85
# BAE Systems                                0.86                0.83
# Rolls-Royce Holdings                      -0.18                0.14
# Thales Group (UK Div)                      0.66                0.68
# Mitsubishi Heavy Ind                       1.00                0.87
# Kawasaki Heavy Ind                         0.87                1.00
# Mitsubishi Electric                       -0.48               -0.33
# Garden Reach Shipbuilders                 -0.82               -0.72
# Mazagon Dock Shipbuilders                 -0.78               -0.71
# Cochin Shipyard                           -0.82               -0.75
#
#                            Mitsubishi Electric  Garden Reach Shipbuilders  \
# Lockheed Martin                          -0.53                      -0.95
# Raytheon Technologies                    -0.48                      -0.92
# General Dynamics                         -0.38                      -0.81
# Northrop Grumman                         -0.54                      -0.95
# BAE Systems                              -0.45                      -0.81
# Rolls-Royce Holdings                      0.36                       0.19
# Thales Group (UK Div)                    -0.40                      -0.71
# Mitsubishi Heavy Ind                     -0.48                      -0.82
# Kawasaki Heavy Ind                       -0.33                      -0.72
# Mitsubishi Electric                       1.00                       0.59
# Garden Reach Shipbuilders                 0.59                       1.00
# Mazagon Dock Shipbuilders                 0.60                       0.97
# Cochin Shipyard                           0.62                       0.98
#
#                            Mazagon Dock Shipbuilders  Cochin Shipyard
# Lockheed Martin                                -0.93            -0.97
# Raytheon Technologies                          -0.91            -0.95
# General Dynamics                               -0.85            -0.80
# Northrop Grumman                               -0.92            -0.95
# BAE Systems                                    -0.75            -0.83
# Rolls-Royce Holdings                            0.12             0.11
# Thales Group (UK Div)                          -0.67            -0.78
# Mitsubishi Heavy Ind                           -0.78            -0.82
# Kawasaki Heavy Ind                             -0.71            -0.75
# Mitsubishi Electric                             0.60             0.62
# Garden Reach Shipbuilders                       0.97             0.98
# Mazagon Dock Shipbuilders                       1.00             0.97
# Cochin Shipyard                                 0.97             1.00
# Event: Red Sea Houthi attacks (start)
#                            Lockheed Martin  Raytheon Technologies  \
# Lockheed Martin                       1.00                   0.89
# Raytheon Technologies                 0.89                   1.00
# General Dynamics                      0.92                   0.89
# Northrop Grumman                      0.94                   0.79
# BAE Systems                           0.66                   0.69
# Rolls-Royce Holdings                 -0.81                  -0.64
# Thales Group (UK Div)                 0.66                   0.41
# Mitsubishi Heavy Ind                  0.69                   0.56
# Kawasaki Heavy Ind                    0.81                   0.63
# Mitsubishi Electric                  -0.43                  -0.59
# Garden Reach Shipbuilders            -0.04                  -0.11
# Mazagon Dock Shipbuilders            -0.16                   0.00
# Cochin Shipyard                      -0.86                  -0.71
#
#                            General Dynamics  Northrop Grumman  BAE Systems  \
# Lockheed Martin                        0.92              0.94         0.66
# Raytheon Technologies                  0.89              0.79         0.69
# General Dynamics                       1.00              0.89         0.62
# Northrop Grumman                       0.89              1.00         0.44
# BAE Systems                            0.62              0.44         1.00
# Rolls-Royce Holdings                  -0.62             -0.67        -0.72
# Thales Group (UK Div)                  0.55              0.76         0.35
# Mitsubishi Heavy Ind                   0.60              0.67         0.49
# Kawasaki Heavy Ind                     0.67              0.79         0.51
# Mitsubishi Electric                   -0.39             -0.28        -0.41
# Garden Reach Shipbuilders             -0.08              0.14        -0.28
# Mazagon Dock Shipbuilders             -0.06             -0.28         0.25
# Cochin Shipyard                       -0.70             -0.75        -0.71
#
#                            Rolls-Royce Holdings  Thales Group (UK Div)  \
# Lockheed Martin                           -0.81                   0.66
# Raytheon Technologies                     -0.64                   0.41
# General Dynamics                          -0.62                   0.55
# Northrop Grumman                          -0.67                   0.76
# BAE Systems                               -0.72                   0.35
# Rolls-Royce Holdings                       1.00                  -0.65
# Thales Group (UK Div)                     -0.65                   1.00
# Mitsubishi Heavy Ind                      -0.75                   0.61
# Kawasaki Heavy Ind                        -0.82                   0.71
# Mitsubishi Electric                        0.44                  -0.04
# Garden Reach Shipbuilders                 -0.01                   0.39
# Mazagon Dock Shipbuilders                 -0.02                  -0.20
# Cochin Shipyard                            0.92                  -0.60
#
#                            Mitsubishi Heavy Ind  Kawasaki Heavy Ind  \
# Lockheed Martin                            0.69                0.81
# Raytheon Technologies                      0.56                0.63
# General Dynamics                           0.60                0.67
# Northrop Grumman                           0.67                0.79
# BAE Systems                                0.49                0.51
# Rolls-Royce Holdings                      -0.75               -0.82
# Thales Group (UK Div)                      0.61                0.71
# Mitsubishi Heavy Ind                       1.00                0.91
# Kawasaki Heavy Ind                         0.91                1.00
# Mitsubishi Electric                       -0.29               -0.37
# Garden Reach Shipbuilders                  0.41                0.29
# Mazagon Dock Shipbuilders                  0.17               -0.06
# Cochin Shipyard                           -0.62               -0.75
#
#                            Mitsubishi Electric  Garden Reach Shipbuilders  \
# Lockheed Martin                          -0.43                      -0.04
# Raytheon Technologies                    -0.59                      -0.11
# General Dynamics                         -0.39                      -0.08
# Northrop Grumman                         -0.28                       0.14
# BAE Systems                              -0.41                      -0.28
# Rolls-Royce Holdings                      0.44                      -0.01
# Thales Group (UK Div)                    -0.04                       0.39
# Mitsubishi Heavy Ind                     -0.29                       0.41
# Kawasaki Heavy Ind                       -0.37                       0.29
# Mitsubishi Electric                       1.00                       0.16
# Garden Reach Shipbuilders                 0.16                       1.00
# Mazagon Dock Shipbuilders                -0.17                       0.30
# Cochin Shipyard                           0.39                       0.23
#
#                            Mazagon Dock Shipbuilders  Cochin Shipyard
# Lockheed Martin                                -0.16            -0.86
# Raytheon Technologies                           0.00            -0.71
# General Dynamics                               -0.06            -0.70
# Northrop Grumman                               -0.28            -0.75
# BAE Systems                                     0.25            -0.71
# Rolls-Royce Holdings                           -0.02             0.92
# Thales Group (UK Div)                          -0.20            -0.60
# Mitsubishi Heavy Ind                            0.17            -0.62
# Kawasaki Heavy Ind                             -0.06            -0.75
# Mitsubishi Electric                            -0.17             0.39
# Garden Reach Shipbuilders                       0.30             0.23
# Mazagon Dock Shipbuilders                       1.00             0.32
# Cochin Shipyard                                 0.32             1.00
# Event: Suez Canal blocked (Ever Given)
#                            Lockheed Martin  Raytheon Technologies  \
# Lockheed Martin                       1.00                  -0.34
# Raytheon Technologies                -0.34                   1.00
# General Dynamics                      0.71                   0.30
# Northrop Grumman                      0.96                  -0.34
# BAE Systems                           0.30                  -0.14
# Rolls-Royce Holdings                 -0.56                   0.72
# Thales Group (UK Div)                 0.50                   0.12
# Mitsubishi Heavy Ind                  0.56                   0.31
# Kawasaki Heavy Ind                    0.39                   0.47
# Mitsubishi Electric                   0.44                   0.39
# Garden Reach Shipbuilders            -0.86                   0.52
# Mazagon Dock Shipbuilders            -0.55                   0.50
# Cochin Shipyard                      -0.43                   0.21
#
#                            General Dynamics  Northrop Grumman  BAE Systems  \
# Lockheed Martin                        0.71              0.96         0.30
# Raytheon Technologies                  0.30             -0.34        -0.14
# General Dynamics                       1.00              0.70         0.19
# Northrop Grumman                       0.70              1.00         0.28
# BAE Systems                            0.19              0.28         1.00
# Rolls-Royce Holdings                  -0.10             -0.61        -0.13
# Thales Group (UK Div)                  0.61              0.44         0.51
# Mitsubishi Heavy Ind                   0.83              0.53         0.10
# Kawasaki Heavy Ind                     0.76              0.37         0.05
# Mitsubishi Electric                    0.82              0.45        -0.00
# Garden Reach Shipbuilders             -0.47             -0.82        -0.17
# Mazagon Dock Shipbuilders             -0.20             -0.58         0.11
# Cochin Shipyard                       -0.37             -0.44         0.19
#
#                            Rolls-Royce Holdings  Thales Group (UK Div)  \
# Lockheed Martin                           -0.56                   0.50
# Raytheon Technologies                      0.72                   0.12
# General Dynamics                          -0.10                   0.61
# Northrop Grumman                          -0.61                   0.44
# BAE Systems                               -0.13                   0.51
# Rolls-Royce Holdings                       1.00                   0.04
# Thales Group (UK Div)                      0.04                   1.00
# Mitsubishi Heavy Ind                      -0.04                   0.56
# Kawasaki Heavy Ind                         0.13                   0.53
# Mitsubishi Electric                       -0.02                   0.50
# Garden Reach Shipbuilders                  0.61                  -0.43
# Mazagon Dock Shipbuilders                  0.52                  -0.16
# Cochin Shipyard                            0.32                  -0.13
#
#                            Mitsubishi Heavy Ind  Kawasaki Heavy Ind  \
# Lockheed Martin                            0.56                0.39
# Raytheon Technologies                      0.31                0.47
# General Dynamics                           0.83                0.76
# Northrop Grumman                           0.53                0.37
# BAE Systems                                0.10                0.05
# Rolls-Royce Holdings                      -0.04                0.13
# Thales Group (UK Div)                      0.56                0.53
# Mitsubishi Heavy Ind                       1.00                0.96
# Kawasaki Heavy Ind                         0.96                1.00
# Mitsubishi Electric                        0.94                0.93
# Garden Reach Shipbuilders                 -0.39               -0.20
# Mazagon Dock Shipbuilders                 -0.14               -0.00
# Cochin Shipyard                           -0.38               -0.27
#
#                            Mitsubishi Electric  Garden Reach Shipbuilders  \
# Lockheed Martin                           0.44                      -0.86
# Raytheon Technologies                     0.39                       0.52
# General Dynamics                          0.82                      -0.47
# Northrop Grumman                          0.45                      -0.82
# BAE Systems                              -0.00                      -0.17
# Rolls-Royce Holdings                     -0.02                       0.61
# Thales Group (UK Div)                     0.50                      -0.43
# Mitsubishi Heavy Ind                      0.94                      -0.39
# Kawasaki Heavy Ind                        0.93                      -0.20
# Mitsubishi Electric                       1.00                      -0.30
# Garden Reach Shipbuilders                -0.30                       1.00
# Mazagon Dock Shipbuilders                -0.14                       0.81
# Cochin Shipyard                          -0.36                       0.57
#
#                            Mazagon Dock Shipbuilders  Cochin Shipyard
# Lockheed Martin                                -0.55            -0.43
# Raytheon Technologies                           0.50             0.21
# General Dynamics                               -0.20            -0.37
# Northrop Grumman                               -0.58            -0.44
# BAE Systems                                     0.11             0.19
# Rolls-Royce Holdings                            0.52             0.32
# Thales Group (UK Div)                          -0.16            -0.13
# Mitsubishi Heavy Ind                           -0.14            -0.38
# Kawasaki Heavy Ind                             -0.00            -0.27
# Mitsubishi Electric                            -0.14            -0.36
# Garden Reach Shipbuilders                       0.81             0.57
# Mazagon Dock Shipbuilders                       1.00             0.66
# Cochin Shipyard                                 0.66             1.00
# Event: Hormuz tanker attacks (escalation)
#                            Lockheed Martin  Raytheon Technologies  \
# Lockheed Martin                       1.00                   0.47
# Raytheon Technologies                 0.47                   1.00
# General Dynamics                     -0.06                   0.65
# Northrop Grumman                      0.92                   0.22
# BAE Systems                          -0.88                  -0.20
# Rolls-Royce Holdings                  0.41                   0.57
# Thales Group (UK Div)                -0.43                   0.15
# Mitsubishi Heavy Ind                  0.63                  -0.09
# Kawasaki Heavy Ind                   -0.89                  -0.73
# Mitsubishi Electric                  -0.78                  -0.32
# Garden Reach Shipbuilders             0.87                   0.34
# Cochin Shipyard                      -0.91                  -0.58
#
#                            General Dynamics  Northrop Grumman  BAE Systems  \
# Lockheed Martin                       -0.06              0.92        -0.88
# Raytheon Technologies                  0.65              0.22        -0.20
# General Dynamics                       1.00             -0.27         0.31
# Northrop Grumman                      -0.27              1.00        -0.92
# BAE Systems                            0.31             -0.92         1.00
# Rolls-Royce Holdings                   0.16              0.28        -0.32
# Thales Group (UK Div)                  0.39             -0.55         0.42
# Mitsubishi Heavy Ind                  -0.62              0.78        -0.76
# Kawasaki Heavy Ind                    -0.16             -0.76         0.68
# Mitsubishi Electric                    0.13             -0.86         0.87
# Garden Reach Shipbuilders             -0.31              0.86        -0.83
# Cochin Shipyard                        0.04             -0.86         0.87
#
#                            Rolls-Royce Holdings  Thales Group (UK Div)  \
# Lockheed Martin                            0.41                  -0.43
# Raytheon Technologies                      0.57                   0.15
# General Dynamics                           0.16                   0.39
# Northrop Grumman                           0.28                  -0.55
# BAE Systems                               -0.32                   0.42
# Rolls-Royce Holdings                       1.00                  -0.05
# Thales Group (UK Div)                     -0.05                   1.00
# Mitsubishi Heavy Ind                       0.20                  -0.55
# Kawasaki Heavy Ind                        -0.47                   0.44
# Mitsubishi Electric                       -0.13                   0.35
# Garden Reach Shipbuilders                  0.50                  -0.69
# Cochin Shipyard                           -0.53                   0.33
#
#                            Mitsubishi Heavy Ind  Kawasaki Heavy Ind  \
# Lockheed Martin                            0.63               -0.89
# Raytheon Technologies                     -0.09               -0.73
# General Dynamics                          -0.62               -0.16
# Northrop Grumman                           0.78               -0.76
# BAE Systems                               -0.76                0.68
# Rolls-Royce Holdings                       0.20               -0.47
# Thales Group (UK Div)                     -0.55                0.44
# Mitsubishi Heavy Ind                       1.00               -0.37
# Kawasaki Heavy Ind                        -0.37                1.00
# Mitsubishi Electric                       -0.65                0.60
# Garden Reach Shipbuilders                  0.71               -0.77
# Cochin Shipyard                           -0.61                0.82
#
#                            Mitsubishi Electric  Garden Reach Shipbuilders  \
# Lockheed Martin                          -0.78                       0.87
# Raytheon Technologies                    -0.32                       0.34
# General Dynamics                          0.13                      -0.31
# Northrop Grumman                         -0.86                       0.86
# BAE Systems                               0.87                      -0.83
# Rolls-Royce Holdings                     -0.13                       0.50
# Thales Group (UK Div)                     0.35                      -0.69
# Mitsubishi Heavy Ind                     -0.65                       0.71
# Kawasaki Heavy Ind                        0.60                      -0.77
# Mitsubishi Electric                       1.00                      -0.65
# Garden Reach Shipbuilders                -0.65                       1.00
# Cochin Shipyard                           0.79                      -0.81
#
#                            Cochin Shipyard
# Lockheed Martin                      -0.91
# Raytheon Technologies                -0.58
# General Dynamics                      0.04
# Northrop Grumman                     -0.86
# BAE Systems                           0.87
# Rolls-Royce Holdings                 -0.53
# Thales Group (UK Div)                 0.33
# Mitsubishi Heavy Ind                 -0.61
# Kawasaki Heavy Ind                    0.82
# Mitsubishi Electric                   0.79
# Garden Reach Shipbuilders            -0.81
# Cochin Shipyard                       1.00
# Event: Maersk Tigris seizure
#                        Lockheed Martin  Raytheon Technologies  \
# Lockheed Martin                   1.00                   0.58
# Raytheon Technologies             0.58                   1.00
# General Dynamics                 -0.53                   0.13
# Northrop Grumman                  0.91                   0.45
# BAE Systems                       0.77                   0.58
# Rolls-Royce Holdings             -0.79                  -0.69
# Thales Group (UK Div)            -0.57                  -0.04
# Mitsubishi Heavy Ind             -0.64                   0.13
# Kawasaki Heavy Ind                0.29                  -0.26
# Mitsubishi Electric              -0.92                  -0.32
#
#                        General Dynamics  Northrop Grumman  BAE Systems  \
# Lockheed Martin                   -0.53              0.91         0.77
# Raytheon Technologies              0.13              0.45         0.58
# General Dynamics                   1.00             -0.68        -0.13
# Northrop Grumman                  -0.68              1.00         0.72
# BAE Systems                       -0.13              0.72         1.00
# Rolls-Royce Holdings               0.33             -0.81        -0.76
# Thales Group (UK Div)              0.35             -0.40        -0.28
# Mitsubishi Heavy Ind               0.75             -0.68        -0.30
# Kawasaki Heavy Ind                -0.19              0.14         0.18
# Mitsubishi Electric                0.55             -0.83        -0.69
#
#                        Rolls-Royce Holdings  Thales Group (UK Div)  \
# Lockheed Martin                       -0.79                  -0.57
# Raytheon Technologies                 -0.69                  -0.04
# General Dynamics                       0.33                   0.35
# Northrop Grumman                      -0.81                  -0.40
# BAE Systems                           -0.76                  -0.28
# Rolls-Royce Holdings                   1.00                   0.35
# Thales Group (UK Div)                  0.35                   1.00
# Mitsubishi Heavy Ind                   0.43                   0.71
# Kawasaki Heavy Ind                     0.19                  -0.34
# Mitsubishi Electric                    0.70                   0.79
#
#                        Mitsubishi Heavy Ind  Kawasaki Heavy Ind  \
# Lockheed Martin                       -0.64                0.29
# Raytheon Technologies                  0.13               -0.26
# General Dynamics                       0.75               -0.19
# Northrop Grumman                      -0.68                0.14
# BAE Systems                           -0.30                0.18
# Rolls-Royce Holdings                   0.43                0.19
# Thales Group (UK Div)                  0.71               -0.34
# Mitsubishi Heavy Ind                   1.00               -0.45
# Kawasaki Heavy Ind                    -0.45                1.00
# Mitsubishi Electric                    0.80               -0.43
#
#                        Mitsubishi Electric
# Lockheed Martin                      -0.92
# Raytheon Technologies                -0.32
# General Dynamics                      0.55
# Northrop Grumman                     -0.83
# BAE Systems                          -0.69
# Rolls-Royce Holdings                  0.70
# Thales Group (UK Div)                 0.79
# Mitsubishi Heavy Ind                  0.80
# Kawasaki Heavy Ind                   -0.43
# Mitsubishi Electric                   1.00
# Event: Tanker War (Iran-Iraq) peak
#                        Lockheed Martin  Raytheon Technologies  \
# Lockheed Martin                   1.00                  -0.33
# Raytheon Technologies            -0.33                   1.00
# General Dynamics                  0.38                  -0.09
# Northrop Grumman                 -0.26                   0.34
#
#                        General Dynamics  Northrop Grumman
# Lockheed Martin                    0.38             -0.26
# Raytheon Technologies             -0.09              0.34
# General Dynamics                   1.00             -0.07
# Northrop Grumman                  -0.07              1.00
# Event: Six-Day War / Suez closure
#                        Lockheed Martin  Raytheon Technologies  \
# Lockheed Martin                   1.00                   0.55
# Raytheon Technologies             0.55                   1.00
# General Dynamics                  0.70                   0.78
#
#                        General Dynamics
# Lockheed Martin                    0.70
# Raytheon Technologies              0.78
# General Dynamics                   1.00
# ================================================================================
# INTERPRETATION NOTES:
#   - Sharpe ratio > 1 is good; volatility is annualized standard deviation of daily returns.
#   - Beneish M-Score < -2.22 suggests no manipulation; > -2.22 suggests possible manipulation.
#   - Altman Z-Score: > 2.99 safe, 1.81-2.99 grey, < 1.81 distress zone (original).
#   - For emerging markets Z'' > 2.60 safe, 1.10-2.60 grey, < 1.10 distress.
#   - Outliers flagged by z-score > 3 indicate ratios unusually far from the group mean.
#   - Correlation heatmaps show how similarly companies' abnormal returns moved around each event.

# %%
"""
Event Study for Indian Stocks Around Maritime Chokepoint Crises
Computes CAR (market-adjusted) for 100+ stocks across 7 historical events
Generates per-stock per-event CAR max/min tables and correlation matrices
"""

import pandas as pd
import numpy as np
import yfinance as yf
import matplotlib.pyplot as plt
import seaborn as sns
from datetime import datetime, timedelta
import warnings
warnings.filterwarnings('ignore')

# ============================================
# 1. Define all stocks with their tickers
# ============================================

STOCKS = {
    # Oil & Gas
    "ONGC": "ONGC.NS",
    "Oil India": "OIL.NS",
    "Indian Oil Corporation": "IOC.NS",
    "Bharat Petroleum": "BPCL.NS",
    "Hindustan Petroleum": "HINDPETRO.NS",
    "Reliance Industries": "RELIANCE.NS",
    "GAIL (India)": "GAIL.NS",
    "Chennai Petroleum": "CHENNPETRO.NS",
    "Gujarat Gas": "GUJGASLTD.NS",
    "Indraprastha Gas": "IGL.NS",
    "Mahanagar Gas": "MGL.NS",
    # Aviation
    "InterGlobe Aviation (IndiGo)": "INDIGO.NS",
    "SpiceJet": "SPICEJET.NS",
    # Shipping, Ports & Logistics
    "Adani Ports & SEZ": "ADANIPORTS.NS",
    "Aegis Logistics": "AEGISLOG.NS",
    "Essar Shipping": "ESSARSHP.NS",
    "Gujarat Pipavav Port": "GPPL.NS",
    "Shipping Corporation of India": "SCI.NS",
    "Great Eastern Shipping": "GESHIP.NS",
    "Gateway Distriparks": "GATEWAY.NS",
    "Delhivery": "DELHIVERY.NS",
    "JSW Infra": "JSWINFRA.NS",
    "GMR Airports": "GMRINFRA.NS",
    "Blue Dart Express": "BLUEDART.NS",
    "TCI Express": "TCIEXP.NS",
    "Allcargo Logistics": "ALLCARGO.NS",
    "Container Corporation (CONCOR)": "CONCOR.NS",
    "Mahindra Logistics": "MAHLOG.NS",
    # Paints
    "Asian Paints": "ASIANPAINT.NS",
    "Berger Paints": "BERGEPAINT.NS",
    "Kansai Nerolac Paints": "KANSAINER.NS",
    "Nippon Paint India": "NIPPONPAINT.NS",
    # Tyres
    "JK Tyre & Industries": "JKTYRE.NS",
    "Apollo Tyres": "APOLLOTYRE.NS",
    "CEAT": "CEATLTD.NS",
    "MRF": "MRF.NS",
    "Balkrishna Industries": "BALKRISIND.NS",
    # Power Generation
    "NTPC": "NTPC.NS",
    "Tata Power": "TATAPOWER.NS",
    "Adani Power": "ADANIPOWER.NS",
    "Power Grid Corporation": "POWERGRID.NS",
    "JSW Energy": "JSWENERGY.NS",
    "Torrent Power": "TORNTPOWER.NS",
    "Crompton Greaves": "CROMPTON.NS",
    "BHEL": "BHEL.NS",
    "Kalpataru Power Transmission": "KPITTECH.NS",
    # Green Energy
    "Solex Energy": "SOLEX.NS",
    "KPI Green Energy": "KPIGREEN.NS",
    "Servotech Renewable Power": "SERVOTECH.NS",
    "Inox Wind": "INOXWIND.NS",
    "Suzlon Energy": "SUZLON.NS",
    "IREDA": "IREDA.NS",
    "Adani Green Energy": "ADANIGREEN.NS",
    "Waaree Renewables": "WAAREEREN.NS",
    "Websol Energy System": "WEBELSOLAR.NS",
    # Chemicals
    "Tata Chemicals": "TATACHEM.NS",
    "Deepak Nitrite": "DEEPAKNTR.NS",
    "SRF Limited": "SRF.NS",
    "Atul Ltd": "ATUL.NS",
    "Aarti Industries": "AARTIIND.NS",
    "Linde India": "LINDEINDIA.NS",
    "Gujarat Fluorochemicals": "GUJFLUORO.NS",
    "Vinati Organics": "VINATIORGA.NS",
    "Navin Fluorine International": "NAVINFLUOR.NS",
    # Automobile
    "Maruti Suzuki": "MARUTI.NS",
    "Tata Motors": "TATAMOTORS.NS",
    "Mahindra & Mahindra": "M&M.NS",
    "Bajaj Auto": "BAJAJ-AUTO.NS",
    "Hero MotoCorp": "HEROMOTOCO.NS",
    "Eicher Motors": "EICHERMOT.NS",
    "TVS Motor Company": "TVSMOTOR.NS",
    "Ashok Leyland": "ASHOKLEY.NS",
    "Force Motors": "FORCEMOT.NS",
    # Steel & Metals
    "Tata Steel": "TATASTEEL.NS",
    "JSW Steel": "JSWSTEEL.NS",
    "Hindalco Industries": "HINDALCO.NS",
    "SAIL": "SAIL.NS",
    "Jindal Steel & Power": "JINDALSTEL.NS",
}

# Remove None and duplicates
clean_stocks = {}
seen = set()
for name, ticker in STOCKS.items():
    if ticker and ticker not in seen:
        clean_stocks[name] = ticker
        seen.add(ticker)

COMPANIES = clean_stocks
print(f"Analyzing {len(COMPANIES)} unique Indian stocks across sectors")

BENCHMARK = "^NSEI"   # Nifty 50

# ============================================
# 2. Define event dates
# ============================================

EVENTS = {
    "Strait of Hormuz Blockade (hypothetical)": "2026-04-12",
    "Red Sea Houthi attacks (start)": "2023-12-01",
    "Suez Canal blocked (Ever Given)": "2021-03-23",
    "Hormuz tanker attacks (escalation)": "2019-05-01",
    "Maersk Tigris seizure": "2015-04-28",
    "U.S.–Iranian Naval Dispute": "2012-01-01",
    "Downing of Iran Air Flight 655": "1988-07-03",
}

WINDOW_DAYS = 30

# ============================================
# 3. Fixed data fetching function (handles MultiIndex correctly)
# ============================================

def fetch_data(tickers, start_date, end_date):
    """
    Download adjusted close prices for a list of tickers.
    Returns DataFrame with columns as tickers.
    Handles both single and multiple tickers, including MultiIndex output from yfinance.
    """
    print(f"Downloading data from {start_date} to {end_date} for {len(tickers)} tickers...")
    data = yf.download(tickers, start=start_date, end=end_date, group_by='ticker', auto_adjust=True, progress=False)
    
    if data.empty:
        return pd.DataFrame()
    
    # Check if the result has a MultiIndex (e.g., from passing a list of tickers)
    if isinstance(data.columns, pd.MultiIndex):
        close_data = {}
        for t in tickers:
            try:
                if t in data.columns.levels[0]:
                    close_data[t] = data[t]['Close']
                else:
                    print(f"Warning: {t} not found in downloaded data.")
            except Exception as e:
                print(f"Error extracting {t}: {e}")
        if not close_data:
            return pd.DataFrame()
        return pd.DataFrame(close_data)
    else:
        # Single ticker without MultiIndex (rare, but safe)
        if len(tickers) == 1 and 'Close' in data.columns:
            return pd.DataFrame({tickers[0]: data['Close']})
        else:
            return pd.DataFrame()

# ============================================
# 4. CAR calculation
# ============================================

def cumulative_abnormal_returns(company_returns, benchmark_returns, event_date, window_days):
    abnormal = company_returns - benchmark_returns
    start = event_date - timedelta(days=window_days)
    end = event_date + timedelta(days=window_days)
    ar_window = abnormal.loc[start:end]
    car = ar_window.cumsum()
    car.index = (car.index - event_date).days
    return car

def run_event_study_for_all(event_dates, window_days):
    all_car = {}
    all_returns = {}
    
    all_event_dates = [pd.to_datetime(d) for d in event_dates.values()]
    min_date = min(all_event_dates) - timedelta(days=window_days+10)
    max_date = max(all_event_dates) + timedelta(days=window_days+10)
    
    # Download benchmark once
    print("Downloading benchmark (Nifty 50)...")
    bench_df = fetch_data([BENCHMARK], min_date.strftime("%Y-%m-%d"), max_date.strftime("%Y-%m-%d"))
    if bench_df.empty or BENCHMARK not in bench_df.columns:
        print("Benchmark data missing. Exiting.")
        return None, None
    benchmark_prices = bench_df[BENCHMARK].dropna()
    benchmark_returns = benchmark_prices.pct_change().dropna()
    
    # Process each company
    for name, ticker in COMPANIES.items():
        print(f"\nProcessing {name} ({ticker})...")
        df = fetch_data([ticker], min_date.strftime("%Y-%m-%d"), max_date.strftime("%Y-%m-%d"))
        if df.empty or ticker not in df.columns:
            print(f"  No data for {ticker}. Skipping.")
            continue
        prices = df[ticker].dropna()
        if len(prices) < 10:
            print(f"  Insufficient price data for {ticker}. Skipping.")
            continue
        returns = prices.pct_change().dropna()
        
        # Align with benchmark
        common_idx = returns.index.intersection(benchmark_returns.index)
        if len(common_idx) < 10:
            print(f"  Insufficient common dates for {ticker}. Skipping.")
            continue
        ret_align = returns[common_idx]
        bench_align = benchmark_returns[common_idx]
        all_returns[name] = ret_align
        
        car_dict = {}
        for event_name, event_date_str in event_dates.items():
            event_date = pd.to_datetime(event_date_str)
            if event_date < common_idx.min() or event_date > common_idx.max():
                print(f"  Event '{event_name}' on {event_date_str} outside data range. Skipping.")
                continue
            car_series = cumulative_abnormal_returns(ret_align, bench_align, event_date, window_days)
            car_dict[event_name] = car_series
        if car_dict:
            car_df = pd.DataFrame(car_dict)
            car_df.index.name = "Days from event"
            all_car[name] = car_df
        else:
            print(f"  No valid events for {ticker}.")
    
    return all_car, all_returns

# ============================================
# 5. Output functions
# ============================================

def print_car_breakdown(all_car):
    print("\n" + "="*80)
    print("EVENT STUDY CUMULATIVE ABNORMAL RETURNS (CAR) – BREAKDOWN BY EVENT")
    for company, car_df in all_car.items():
        print(f"\n{company}:")
        for event in car_df.columns:
            max_car = car_df[event].max()
            min_car = car_df[event].min()
            print(f"  {event}: max CAR = {max_car:.2%}, min CAR = {min_car:.2%}")

def compute_correlation_matrices(all_car):
    event_to_companies = {}
    for company, car_df in all_car.items():
        for event in car_df.columns:
            if event not in event_to_companies:
                event_to_companies[event] = {}
            event_to_companies[event][company] = car_df[event]
    
    correlations = {}
    for event, company_series in event_to_companies.items():
        common_idx = None
        for ser in company_series.values():
            if common_idx is None:
                common_idx = ser.index
            else:
                common_idx = common_idx.intersection(ser.index)
        if len(common_idx) < 2:
            print(f"Event {event}: not enough overlapping days. Skipping correlation.")
            continue
        df = pd.DataFrame({comp: ser.loc[common_idx] for comp, ser in company_series.items()})
        corr_mat = df.corr()
        correlations[event] = corr_mat
    return correlations

def plot_correlation_heatmaps(correlations):
    for event, corr_mat in correlations.items():
        if corr_mat.empty:
            continue
        plt.figure(figsize=(12, 10))
        sns.heatmap(corr_mat, annot=False, cmap='coolwarm', center=0,
                    square=True, linewidths=0.5, cbar_kws={"shrink": 0.8})
        plt.title(f"CAR Correlation Matrix – {event}")
        plt.tight_layout()
        plt.show()

# def save_correlation_matrices(correlations):
#     for event, corr_mat in correlations.items():
#         filename = f"CAR_correlation_{event.replace(' ', '_').replace('–','-')}.csv"
#         corr_mat.to_csv(filename)
#         print(f"Saved {filename}")

# ============================================
# 6. Main execution
# ============================================

if __name__ == "__main__":
    print("Starting event study for Indian maritime-sensitive stocks...")
    all_car, _ = run_event_study_for_all(EVENTS, WINDOW_DAYS)
    
    if not all_car:
        print("No CAR data generated. Exiting.")
        exit()
    
    print_car_breakdown(all_car)
    
    print("\n" + "-"*80)
    print("Computing correlation matrices for each event...")
    corrs = compute_correlation_matrices(all_car)
    
    if corrs:
        # save_correlation_matrices(corrs)
        plot_correlation_heatmaps(corrs)
    else:
        print("No correlation matrices computed.")
    
    print("\nAnalysis complete.")
# Out:
# Analyzing 78 unique Indian stocks across sectors
# Starting event study for Indian maritime-sensitive stocks...
# Downloading benchmark (Nifty 50)...
# Downloading data from 1988-05-24 to 2026-05-22 for 1 tickers...
#
# Processing ONGC (ONGC.NS)...
# Downloading data from 1988-05-24 to 2026-05-22 for 1 tickers...
#   Event 'Downing of Iran Air Flight 655' on 1988-07-03 outside data range. Skipping.
#
# Processing Oil India (OIL.NS)...
# Downloading data from 1988-05-24 to 2026-05-22 for 1 tickers...
#   Event 'Downing of Iran Air Flight 655' on 1988-07-03 outside data range. Skipping.
#
# Processing Indian Oil Corporation (IOC.NS)...
# Downloading data from 1988-05-24 to 2026-05-22 for 1 tickers...
#   Event 'Downing of Iran Air Flight 655' on 1988-07-03 outside data range. Skipping.
#
# Processing Bharat Petroleum (BPCL.NS)...
# Downloading data from 1988-05-24 to 2026-05-22 for 1 tickers...
#   Event 'Downing of Iran Air Flight 655' on 1988-07-03 outside data range. Skipping.
#
# Processing Hindustan Petroleum (HINDPETRO.NS)...
# Downloading data from 1988-05-24 to 2026-05-22 for 1 tickers...
#   Event 'Downing of Iran Air Flight 655' on 1988-07-03 outside data range. Skipping.
#
# Processing Reliance Industries (RELIANCE.NS)...
# Downloading data from 1988-05-24 to 2026-05-22 for 1 tickers...
#   Event 'Downing of Iran Air Flight 655' on 1988-07-03 outside data range. Skipping.
#
# Processing GAIL (India) (GAIL.NS)...
# Downloading data from 1988-05-24 to 2026-05-22 for 1 tickers...
#   Event 'Downing of Iran Air Flight 655' on 1988-07-03 outside data range. Skipping.
#
# Processing Chennai Petroleum (CHENNPETRO.NS)...
# Downloading data from 1988-05-24 to 2026-05-22 for 1 tickers...
#   Event 'Downing of Iran Air Flight 655' on 1988-07-03 outside data range. Skipping.
#
# Processing Gujarat Gas (GUJGASLTD.NS)...
# Downloading data from 1988-05-24 to 2026-05-22 for 1 tickers...
#   Event 'Maersk Tigris seizure' on 2015-04-28 outside data range. Skipping.
#   Event 'U.S.–Iranian Naval Dispute' on 2012-01-01 outside data range. Skipping.
#   Event 'Downing of Iran Air Flight 655' on 1988-07-03 outside data range. Skipping.
#
# Processing Indraprastha Gas (IGL.NS)...
# Downloading data from 1988-05-24 to 2026-05-22 for 1 tickers...
#   Event 'Downing of Iran Air Flight 655' on 1988-07-03 outside data range. Skipping.
#
# Processing Mahanagar Gas (MGL.NS)...
# Downloading data from 1988-05-24 to 2026-05-22 for 1 tickers...
#   Event 'Maersk Tigris seizure' on 2015-04-28 outside data range. Skipping.
#   Event 'U.S.–Iranian Naval Dispute' on 2012-01-01 outside data range. Skipping.
#   Event 'Downing of Iran Air Flight 655' on 1988-07-03 outside data range. Skipping.
#
# Processing InterGlobe Aviation (IndiGo) (INDIGO.NS)...
# Downloading data from 1988-05-24 to 2026-05-22 for 1 tickers...
#   Event 'Maersk Tigris seizure' on 2015-04-28 outside data range. Skipping.
#   Event 'U.S.–Iranian Naval Dispute' on 2012-01-01 outside data range. Skipping.
#   Event 'Downing of Iran Air Flight 655' on 1988-07-03 outside data range. Skipping.
#
# Processing SpiceJet (SPICEJET.NS)...
# Downloading data from 1988-05-24 to 2026-05-22 for 1 tickers...
# HTTP Error 404: {"quoteSummary":{"result":null,"error":{"code":"Not Found","description":"Quote not found for symbol: SPICEJET.NS"}}}
# $SPICEJET.NS: possibly delisted; no timezone found
#
# 1 Failed download:
# ['SPICEJET.NS']: possibly delisted; no timezone found
#   No data for SPICEJET.NS. Skipping.
#
# Processing Adani Ports & SEZ (ADANIPORTS.NS)...
# Downloading data from 1988-05-24 to 2026-05-22 for 1 tickers...
#   Event 'Downing of Iran Air Flight 655' on 1988-07-03 outside data range. Skipping.
#
# Processing Aegis Logistics (AEGISLOG.NS)...
# Downloading data from 1988-05-24 to 2026-05-22 for 1 tickers...
#   Event 'Red Sea Houthi attacks (start)' on 2023-12-01 outside data range. Skipping.
#   Event 'Suez Canal blocked (Ever Given)' on 2021-03-23 outside data range. Skipping.
#   Event 'Hormuz tanker attacks (escalation)' on 2019-05-01 outside data range. Skipping.
#   Event 'Maersk Tigris seizure' on 2015-04-28 outside data range. Skipping.
#   Event 'U.S.–Iranian Naval Dispute' on 2012-01-01 outside data range. Skipping.
#   Event 'Downing of Iran Air Flight 655' on 1988-07-03 outside data range. Skipping.
#
# Processing Essar Shipping (ESSARSHP.NS)...
# Downloading data from 1988-05-24 to 2026-05-22 for 1 tickers...
# HTTP Error 404: {"quoteSummary":{"result":null,"error":{"code":"Not Found","description":"Quote not found for symbol: ESSARSHP.NS"}}}
# $ESSARSHP.NS: possibly delisted; no timezone found
#
# 1 Failed download:
# ['ESSARSHP.NS']: possibly delisted; no timezone found
#   No data for ESSARSHP.NS. Skipping.
#
# Processing Gujarat Pipavav Port (GPPL.NS)...
# Downloading data from 1988-05-24 to 2026-05-22 for 1 tickers...
#   Event 'Downing of Iran Air Flight 655' on 1988-07-03 outside data range. Skipping.
#
# Processing Shipping Corporation of India (SCI.NS)...
# Downloading data from 1988-05-24 to 2026-05-22 for 1 tickers...
#   Event 'Downing of Iran Air Flight 655' on 1988-07-03 outside data range. Skipping.
#
# Processing Great Eastern Shipping (GESHIP.NS)...
# Downloading data from 1988-05-24 to 2026-05-22 for 1 tickers...
#   Event 'Downing of Iran Air Flight 655' on 1988-07-03 outside data range. Skipping.
#
# Processing Gateway Distriparks (GATEWAY.NS)...
# Downloading data from 1988-05-24 to 2026-05-22 for 1 tickers...
#   Event 'Suez Canal blocked (Ever Given)' on 2021-03-23 outside data range. Skipping.
#   Event 'Hormuz tanker attacks (escalation)' on 2019-05-01 outside data range. Skipping.
#   Event 'Maersk Tigris seizure' on 2015-04-28 outside data range. Skipping.
#   Event 'U.S.–Iranian Naval Dispute' on 2012-01-01 outside data range. Skipping.
#   Event 'Downing of Iran Air Flight 655' on 1988-07-03 outside data range. Skipping.
#
# Processing Delhivery (DELHIVERY.NS)...
# Downloading data from 1988-05-24 to 2026-05-22 for 1 tickers...
#   Event 'Suez Canal blocked (Ever Given)' on 2021-03-23 outside data range. Skipping.
#   Event 'Hormuz tanker attacks (escalation)' on 2019-05-01 outside data range. Skipping.
#   Event 'Maersk Tigris seizure' on 2015-04-28 outside data range. Skipping.
#   Event 'U.S.–Iranian Naval Dispute' on 2012-01-01 outside data range. Skipping.
#   Event 'Downing of Iran Air Flight 655' on 1988-07-03 outside data range. Skipping.
#
# Processing JSW Infra (JSWINFRA.NS)...
# Downloading data from 1988-05-24 to 2026-05-22 for 1 tickers...
#   Event 'Suez Canal blocked (Ever Given)' on 2021-03-23 outside data range. Skipping.
#   Event 'Hormuz tanker attacks (escalation)' on 2019-05-01 outside data range. Skipping.
#   Event 'Maersk Tigris seizure' on 2015-04-28 outside data range. Skipping.
#   Event 'U.S.–Iranian Naval Dispute' on 2012-01-01 outside data range. Skipping.
#   Event 'Downing of Iran Air Flight 655' on 1988-07-03 outside data range. Skipping.
#
# Processing GMR Airports (GMRINFRA.NS)...
# Downloading data from 1988-05-24 to 2026-05-22 for 1 tickers...
# $GMRINFRA.NS: possibly delisted; no timezone found
#
# 1 Failed download:
# ['GMRINFRA.NS']: possibly delisted; no timezone found
#   No data for GMRINFRA.NS. Skipping.
#
# Processing Blue Dart Express (BLUEDART.NS)...
# Downloading data from 1988-05-24 to 2026-05-22 for 1 tickers...
#   Event 'Downing of Iran Air Flight 655' on 1988-07-03 outside data range. Skipping.
#
# Processing TCI Express (TCIEXP.NS)...
# Downloading data from 1988-05-24 to 2026-05-22 for 1 tickers...
#   Event 'Maersk Tigris seizure' on 2015-04-28 outside data range. Skipping.
#   Event 'U.S.–Iranian Naval Dispute' on 2012-01-01 outside data range. Skipping.
#   Event 'Downing of Iran Air Flight 655' on 1988-07-03 outside data range. Skipping.
#
# Processing Allcargo Logistics (ALLCARGO.NS)...
# Downloading data from 1988-05-24 to 2026-05-22 for 1 tickers...
#   Event 'Downing of Iran Air Flight 655' on 1988-07-03 outside data range. Skipping.
#
# Processing Container Corporation (CONCOR) (CONCOR.NS)...
# Downloading data from 1988-05-24 to 2026-05-22 for 1 tickers...
#   Event 'Downing of Iran Air Flight 655' on 1988-07-03 outside data range. Skipping.
#
# Processing Mahindra Logistics (MAHLOG.NS)...
# Downloading data from 1988-05-24 to 2026-05-22 for 1 tickers...
#   Event 'Maersk Tigris seizure' on 2015-04-28 outside data range. Skipping.
#   Event 'U.S.–Iranian Naval Dispute' on 2012-01-01 outside data range. Skipping.
#   Event 'Downing of Iran Air Flight 655' on 1988-07-03 outside data range. Skipping.
#
# Processing Asian Paints (ASIANPAINT.NS)...
# Downloading data from 1988-05-24 to 2026-05-22 for 1 tickers...
#   Event 'Downing of Iran Air Flight 655' on 1988-07-03 outside data range. Skipping.
#
# Processing Berger Paints (BERGEPAINT.NS)...
# Downloading data from 1988-05-24 to 2026-05-22 for 1 tickers...
#   Event 'Downing of Iran Air Flight 655' on 1988-07-03 outside data range. Skipping.
#
# Processing Kansai Nerolac Paints (KANSAINER.NS)...
# Downloading data from 1988-05-24 to 2026-05-22 for 1 tickers...
#   Event 'Downing of Iran Air Flight 655' on 1988-07-03 outside data range. Skipping.
#
# Processing Nippon Paint India (NIPPONPAINT.NS)...
# Downloading data from 1988-05-24 to 2026-05-22 for 1 tickers...
# $NIPPONPAINT.NS: possibly delisted; no timezone found
#
# 1 Failed download:
# ['NIPPONPAINT.NS']: possibly delisted; no timezone found
#   No data for NIPPONPAINT.NS. Skipping.
#
# Processing JK Tyre & Industries (JKTYRE.NS)...
# Downloading data from 1988-05-24 to 2026-05-22 for 1 tickers...
#   Event 'Downing of Iran Air Flight 655' on 1988-07-03 outside data range. Skipping.
#
# Processing Apollo Tyres (APOLLOTYRE.NS)...
# Downloading data from 1988-05-24 to 2026-05-22 for 1 tickers...
#   Event 'Downing of Iran Air Flight 655' on 1988-07-03 outside data range. Skipping.
#
# Processing CEAT (CEATLTD.NS)...
# Downloading data from 1988-05-24 to 2026-05-22 for 1 tickers...
#   Event 'Downing of Iran Air Flight 655' on 1988-07-03 outside data range. Skipping.
#
# Processing MRF (MRF.NS)...
# Downloading data from 1988-05-24 to 2026-05-22 for 1 tickers...
#   Event 'Downing of Iran Air Flight 655' on 1988-07-03 outside data range. Skipping.
#
# Processing Balkrishna Industries (BALKRISIND.NS)...
# Downloading data from 1988-05-24 to 2026-05-22 for 1 tickers...
#   Event 'Downing of Iran Air Flight 655' on 1988-07-03 outside data range. Skipping.
#
# Processing NTPC (NTPC.NS)...
# Downloading data from 1988-05-24 to 2026-05-22 for 1 tickers...
#   Event 'Downing of Iran Air Flight 655' on 1988-07-03 outside data range. Skipping.
#
# Processing Tata Power (TATAPOWER.NS)...
# Downloading data from 1988-05-24 to 2026-05-22 for 1 tickers...
#   Event 'Downing of Iran Air Flight 655' on 1988-07-03 outside data range. Skipping.
#
# Processing Adani Power (ADANIPOWER.NS)...
# Downloading data from 1988-05-24 to 2026-05-22 for 1 tickers...
#   Event 'Downing of Iran Air Flight 655' on 1988-07-03 outside data range. Skipping.
#
# Processing Power Grid Corporation (POWERGRID.NS)...
# Downloading data from 1988-05-24 to 2026-05-22 for 1 tickers...
#   Event 'Downing of Iran Air Flight 655' on 1988-07-03 outside data range. Skipping.
#
# Processing JSW Energy (JSWENERGY.NS)...
# Downloading data from 1988-05-24 to 2026-05-22 for 1 tickers...
#   Event 'Downing of Iran Air Flight 655' on 1988-07-03 outside data range. Skipping.
#
# Processing Torrent Power (TORNTPOWER.NS)...
# Downloading data from 1988-05-24 to 2026-05-22 for 1 tickers...
#   Event 'Downing of Iran Air Flight 655' on 1988-07-03 outside data range. Skipping.
#
# Processing Crompton Greaves (CROMPTON.NS)...
# Downloading data from 1988-05-24 to 2026-05-22 for 1 tickers...
#   Event 'Maersk Tigris seizure' on 2015-04-28 outside data range. Skipping.
#   Event 'U.S.–Iranian Naval Dispute' on 2012-01-01 outside data range. Skipping.
#   Event 'Downing of Iran Air Flight 655' on 1988-07-03 outside data range. Skipping.
#
# Processing BHEL (BHEL.NS)...
# Downloading data from 1988-05-24 to 2026-05-22 for 1 tickers...
#   Event 'Downing of Iran Air Flight 655' on 1988-07-03 outside data range. Skipping.
#
# Processing Kalpataru Power Transmission (KPITTECH.NS)...
# Downloading data from 1988-05-24 to 2026-05-22 for 1 tickers...
#   Event 'Maersk Tigris seizure' on 2015-04-28 outside data range. Skipping.
#   Event 'U.S.–Iranian Naval Dispute' on 2012-01-01 outside data range. Skipping.
#   Event 'Downing of Iran Air Flight 655' on 1988-07-03 outside data range. Skipping.
#
# Processing Solex Energy (SOLEX.NS)...
# Downloading data from 1988-05-24 to 2026-05-22 for 1 tickers...
#   Event 'Maersk Tigris seizure' on 2015-04-28 outside data range. Skipping.
#   Event 'U.S.–Iranian Naval Dispute' on 2012-01-01 outside data range. Skipping.
#   Event 'Downing of Iran Air Flight 655' on 1988-07-03 outside data range. Skipping.
#
# Processing KPI Green Energy (KPIGREEN.NS)...
# Downloading data from 1988-05-24 to 2026-05-22 for 1 tickers...
#   Event 'Suez Canal blocked (Ever Given)' on 2021-03-23 outside data range. Skipping.
#   Event 'Hormuz tanker attacks (escalation)' on 2019-05-01 outside data range. Skipping.
#   Event 'Maersk Tigris seizure' on 2015-04-28 outside data range. Skipping.
#   Event 'U.S.–Iranian Naval Dispute' on 2012-01-01 outside data range. Skipping.
#   Event 'Downing of Iran Air Flight 655' on 1988-07-03 outside data range. Skipping.
#
# Processing Servotech Renewable Power (SERVOTECH.NS)...
# Downloading data from 1988-05-24 to 2026-05-22 for 1 tickers...
#   Event 'Maersk Tigris seizure' on 2015-04-28 outside data range. Skipping.
#   Event 'U.S.–Iranian Naval Dispute' on 2012-01-01 outside data range. Skipping.
#   Event 'Downing of Iran Air Flight 655' on 1988-07-03 outside data range. Skipping.
#
# Processing Inox Wind (INOXWIND.NS)...
# Downloading data from 1988-05-24 to 2026-05-22 for 1 tickers...
#   Event 'U.S.–Iranian Naval Dispute' on 2012-01-01 outside data range. Skipping.
#   Event 'Downing of Iran Air Flight 655' on 1988-07-03 outside data range. Skipping.
#
# Processing Suzlon Energy (SUZLON.NS)...
# Downloading data from 1988-05-24 to 2026-05-22 for 1 tickers...
#   Event 'Downing of Iran Air Flight 655' on 1988-07-03 outside data range. Skipping.
#
# Processing IREDA (IREDA.NS)...
# Downloading data from 1988-05-24 to 2026-05-22 for 1 tickers...
#   Event 'Suez Canal blocked (Ever Given)' on 2021-03-23 outside data range. Skipping.
#   Event 'Hormuz tanker attacks (escalation)' on 2019-05-01 outside data range. Skipping.
#   Event 'Maersk Tigris seizure' on 2015-04-28 outside data range. Skipping.
#   Event 'U.S.–Iranian Naval Dispute' on 2012-01-01 outside data range. Skipping.
#   Event 'Downing of Iran Air Flight 655' on 1988-07-03 outside data range. Skipping.
#
# Processing Adani Green Energy (ADANIGREEN.NS)...
# Downloading data from 1988-05-24 to 2026-05-22 for 1 tickers...
#   Event 'Maersk Tigris seizure' on 2015-04-28 outside data range. Skipping.
#   Event 'U.S.–Iranian Naval Dispute' on 2012-01-01 outside data range. Skipping.
#   Event 'Downing of Iran Air Flight 655' on 1988-07-03 outside data range. Skipping.
#
# Processing Waaree Renewables (WAAREEREN.NS)...
# Downloading data from 1988-05-24 to 2026-05-22 for 1 tickers...
# $WAAREEREN.NS: possibly delisted; no timezone found
#
# 1 Failed download:
# ['WAAREEREN.NS']: possibly delisted; no timezone found
#   No data for WAAREEREN.NS. Skipping.
#
# Processing Websol Energy System (WEBELSOLAR.NS)...
# Downloading data from 1988-05-24 to 2026-05-22 for 1 tickers...
#   Event 'Downing of Iran Air Flight 655' on 1988-07-03 outside data range. Skipping.
#
# Processing Tata Chemicals (TATACHEM.NS)...
# Downloading data from 1988-05-24 to 2026-05-22 for 1 tickers...
#   Event 'Downing of Iran Air Flight 655' on 1988-07-03 outside data range. Skipping.
#
# Processing Deepak Nitrite (DEEPAKNTR.NS)...
# Downloading data from 1988-05-24 to 2026-05-22 for 1 tickers...
#   Event 'Downing of Iran Air Flight 655' on 1988-07-03 outside data range. Skipping.
#
# Processing SRF Limited (SRF.NS)...
# Downloading data from 1988-05-24 to 2026-05-22 for 1 tickers...
#   Event 'Downing of Iran Air Flight 655' on 1988-07-03 outside data range. Skipping.
#
# Processing Atul Ltd (ATUL.NS)...
# Downloading data from 1988-05-24 to 2026-05-22 for 1 tickers...
#   Event 'Downing of Iran Air Flight 655' on 1988-07-03 outside data range. Skipping.
#
# Processing Aarti Industries (AARTIIND.NS)...
# Downloading data from 1988-05-24 to 2026-05-22 for 1 tickers...
#   Event 'Downing of Iran Air Flight 655' on 1988-07-03 outside data range. Skipping.
#
# Processing Linde India (LINDEINDIA.NS)...
# Downloading data from 1988-05-24 to 2026-05-22 for 1 tickers...
#   Event 'Downing of Iran Air Flight 655' on 1988-07-03 outside data range. Skipping.
#
# Processing Gujarat Fluorochemicals (GUJFLUORO.NS)...
# Downloading data from 1988-05-24 to 2026-05-22 for 1 tickers...
# $GUJFLUORO.NS: possibly delisted; no timezone found
#
# 1 Failed download:
# ['GUJFLUORO.NS']: possibly delisted; no timezone found
#   No data for GUJFLUORO.NS. Skipping.
#
# Processing Vinati Organics (VINATIORGA.NS)...
# Downloading data from 1988-05-24 to 2026-05-22 for 1 tickers...
#   Event 'Downing of Iran Air Flight 655' on 1988-07-03 outside data range. Skipping.
#
# Processing Navin Fluorine International (NAVINFLUOR.NS)...
# Downloading data from 1988-05-24 to 2026-05-22 for 1 tickers...
#   Event 'Downing of Iran Air Flight 655' on 1988-07-03 outside data range. Skipping.
#
# Processing Maruti Suzuki (MARUTI.NS)...
# Downloading data from 1988-05-24 to 2026-05-22 for 1 tickers...
#   Event 'Downing of Iran Air Flight 655' on 1988-07-03 outside data range. Skipping.
#
# Processing Tata Motors (TATAMOTORS.NS)...
# Downloading data from 1988-05-24 to 2026-05-22 for 1 tickers...
# $TATAMOTORS.NS: possibly delisted; no timezone found
#
# 1 Failed download:
# ['TATAMOTORS.NS']: possibly delisted; no timezone found
#   No data for TATAMOTORS.NS. Skipping.
#
# Processing Mahindra & Mahindra (M&M.NS)...
# Downloading data from 1988-05-24 to 2026-05-22 for 1 tickers...
#   Event 'Downing of Iran Air Flight 655' on 1988-07-03 outside data range. Skipping.
#
# Processing Bajaj Auto (BAJAJ-AUTO.NS)...
# Downloading data from 1988-05-24 to 2026-05-22 for 1 tickers...
#   Event 'Downing of Iran Air Flight 655' on 1988-07-03 outside data range. Skipping.
#
# Processing Hero MotoCorp (HEROMOTOCO.NS)...
# Downloading data from 1988-05-24 to 2026-05-22 for 1 tickers...
#   Event 'Downing of Iran Air Flight 655' on 1988-07-03 outside data range. Skipping.
#
# Processing Eicher Motors (EICHERMOT.NS)...
# Downloading data from 1988-05-24 to 2026-05-22 for 1 tickers...
#   Event 'Downing of Iran Air Flight 655' on 1988-07-03 outside data range. Skipping.
#
# Processing TVS Motor Company (TVSMOTOR.NS)...
# Downloading data from 1988-05-24 to 2026-05-22 for 1 tickers...
#   Event 'Downing of Iran Air Flight 655' on 1988-07-03 outside data range. Skipping.
#
# Processing Ashok Leyland (ASHOKLEY.NS)...
# Downloading data from 1988-05-24 to 2026-05-22 for 1 tickers...
#   Event 'Downing of Iran Air Flight 655' on 1988-07-03 outside data range. Skipping.
#
# Processing Force Motors (FORCEMOT.NS)...
# Downloading data from 1988-05-24 to 2026-05-22 for 1 tickers...
#   Event 'Hormuz tanker attacks (escalation)' on 2019-05-01 outside data range. Skipping.
#   Event 'Maersk Tigris seizure' on 2015-04-28 outside data range. Skipping.
#   Event 'U.S.–Iranian Naval Dispute' on 2012-01-01 outside data range. Skipping.
#   Event 'Downing of Iran Air Flight 655' on 1988-07-03 outside data range. Skipping.
#
# Processing Tata Steel (TATASTEEL.NS)...
# Downloading data from 1988-05-24 to 2026-05-22 for 1 tickers...
#   Event 'Downing of Iran Air Flight 655' on 1988-07-03 outside data range. Skipping.
#
# Processing JSW Steel (JSWSTEEL.NS)...
# Downloading data from 1988-05-24 to 2026-05-22 for 1 tickers...
#   Event 'Downing of Iran Air Flight 655' on 1988-07-03 outside data range. Skipping.
#
# Processing Hindalco Industries (HINDALCO.NS)...
# Downloading data from 1988-05-24 to 2026-05-22 for 1 tickers...
#   Event 'Downing of Iran Air Flight 655' on 1988-07-03 outside data range. Skipping.
#
# Processing SAIL (SAIL.NS)...
# Downloading data from 1988-05-24 to 2026-05-22 for 1 tickers...
#   Event 'Downing of Iran Air Flight 655' on 1988-07-03 outside data range. Skipping.
#
# Processing Jindal Steel & Power (JINDALSTEL.NS)...
# Downloading data from 1988-05-24 to 2026-05-22 for 1 tickers...
#   Event 'Downing of Iran Air Flight 655' on 1988-07-03 outside data range. Skipping.
#
# ================================================================================
# EVENT STUDY CUMULATIVE ABNORMAL RETURNS (CAR) – BREAKDOWN BY EVENT
#
# ONGC:
#   Strait of Hormuz Blockade (hypothetical): max CAR = 10.75%, min CAR = -2.81%
#   Red Sea Houthi attacks (start): max CAR = 4.61%, min CAR = -2.35%
#   Suez Canal blocked (Ever Given): max CAR = 12.78%, min CAR = -1.48%
#   Hormuz tanker attacks (escalation): max CAR = 11.49%, min CAR = -0.92%
#   Maersk Tigris seizure: max CAR = 10.69%, min CAR = -3.42%
#   U.S.–Iranian Naval Dispute: max CAR = 3.52%, min CAR = -1.97%
#
# Oil India:
#   Strait of Hormuz Blockade (hypothetical): max CAR = 4.87%, min CAR = -8.72%
#   Red Sea Houthi attacks (start): max CAR = 14.96%, min CAR = -3.89%
#   Suez Canal blocked (Ever Given): max CAR = 10.24%, min CAR = -1.18%
#   Hormuz tanker attacks (escalation): max CAR = -1.14%, min CAR = -5.78%
#   Maersk Tigris seizure: max CAR = 6.00%, min CAR = -5.56%
#   U.S.–Iranian Naval Dispute: max CAR = 11.22%, min CAR = -1.65%
#
# Indian Oil Corporation:
#   Strait of Hormuz Blockade (hypothetical): max CAR = -0.20%, min CAR = -15.12%
#   Red Sea Houthi attacks (start): max CAR = 32.31%, min CAR = 3.54%
#   Suez Canal blocked (Ever Given): max CAR = 6.22%, min CAR = -3.50%
#   Hormuz tanker attacks (escalation): max CAR = 0.34%, min CAR = -8.15%
#   Maersk Tigris seizure: max CAR = 7.40%, min CAR = -0.72%
#   U.S.–Iranian Naval Dispute: max CAR = 10.86%, min CAR = 0.88%
#
# Bharat Petroleum:
#   Strait of Hormuz Blockade (hypothetical): max CAR = -0.10%, min CAR = -13.66%
#   Red Sea Houthi attacks (start): max CAR = 22.00%, min CAR = 2.66%
#   Suez Canal blocked (Ever Given): max CAR = 9.25%, min CAR = -1.68%
#   Hormuz tanker attacks (escalation): max CAR = 3.95%, min CAR = -13.35%
#   Maersk Tigris seizure: max CAR = 11.72%, min CAR = 0.82%
#   U.S.–Iranian Naval Dispute: max CAR = 6.92%, min CAR = -8.62%
#
# Hindustan Petroleum:
#   Strait of Hormuz Blockade (hypothetical): max CAR = 2.39%, min CAR = -13.74%
#   Red Sea Houthi attacks (start): max CAR = 41.37%, min CAR = 2.19%
#   Suez Canal blocked (Ever Given): max CAR = 2.94%, min CAR = -4.93%
#   Hormuz tanker attacks (escalation): max CAR = 16.07%, min CAR = -8.22%
#   Maersk Tigris seizure: max CAR = 4.83%, min CAR = -4.04%
#   U.S.–Iranian Naval Dispute: max CAR = 7.82%, min CAR = -8.71%
#
# Reliance Industries:
#   Strait of Hormuz Blockade (hypothetical): max CAR = 5.92%, min CAR = -6.65%
#   Red Sea Houthi attacks (start): max CAR = 1.12%, min CAR = -3.34%
#   Suez Canal blocked (Ever Given): max CAR = 5.51%, min CAR = -4.65%
#   Hormuz tanker attacks (escalation): max CAR = 2.47%, min CAR = -6.34%
#   Maersk Tigris seizure: max CAR = 12.42%, min CAR = -2.16%
#   U.S.–Iranian Naval Dispute: max CAR = -0.66%, min CAR = -13.39%
#
# GAIL (India):
#   Strait of Hormuz Blockade (hypothetical): max CAR = 7.58%, min CAR = -7.41%
#   Red Sea Houthi attacks (start): max CAR = 18.41%, min CAR = -1.12%
#   Suez Canal blocked (Ever Given): max CAR = 6.32%, min CAR = -6.14%
#   Hormuz tanker attacks (escalation): max CAR = -0.01%, min CAR = -7.09%
#   Maersk Tigris seizure: max CAR = 3.99%, min CAR = -4.83%
#   U.S.–Iranian Naval Dispute: max CAR = 3.33%, min CAR = -13.57%
#
# Chennai Petroleum:
#   Strait of Hormuz Blockade (hypothetical): max CAR = 19.47%, min CAR = -0.65%
#   Red Sea Houthi attacks (start): max CAR = 10.19%, min CAR = -2.07%
#   Suez Canal blocked (Ever Given): max CAR = 22.98%, min CAR = 0.13%
#   Hormuz tanker attacks (escalation): max CAR = 3.13%, min CAR = -25.25%
#   Maersk Tigris seizure: max CAR = 67.47%, min CAR = 1.73%
#   U.S.–Iranian Naval Dispute: max CAR = -2.06%, min CAR = -15.28%
#
# Gujarat Gas:
#   Strait of Hormuz Blockade (hypothetical): max CAR = 3.16%, min CAR = -21.75%
#   Red Sea Houthi attacks (start): max CAR = 1.76%, min CAR = -3.31%
#   Suez Canal blocked (Ever Given): max CAR = 15.21%, min CAR = -0.65%
#   Hormuz tanker attacks (escalation): max CAR = 22.88%, min CAR = -0.23%
#
# Indraprastha Gas:
#   Strait of Hormuz Blockade (hypothetical): max CAR = 2.18%, min CAR = -6.77%
#   Red Sea Houthi attacks (start): max CAR = 3.93%, min CAR = -6.10%
#   Suez Canal blocked (Ever Given): max CAR = 1.40%, min CAR = -7.87%
#   Hormuz tanker attacks (escalation): max CAR = 6.33%, min CAR = -4.00%
#   Maersk Tigris seizure: max CAR = 9.62%, min CAR = -4.37%
#   U.S.–Iranian Naval Dispute: max CAR = -0.78%, min CAR = -26.86%
#
# Mahanagar Gas:
#   Strait of Hormuz Blockade (hypothetical): max CAR = 9.21%, min CAR = -9.68%
#   Red Sea Houthi attacks (start): max CAR = 4.00%, min CAR = -4.95%
#   Suez Canal blocked (Ever Given): max CAR = 3.93%, min CAR = -5.47%
#   Hormuz tanker attacks (escalation): max CAR = -2.04%, min CAR = -21.34%
#
# InterGlobe Aviation (IndiGo):
#   Strait of Hormuz Blockade (hypothetical): max CAR = 7.67%, min CAR = -2.42%
#   Red Sea Houthi attacks (start): max CAR = 10.49%, min CAR = -0.95%
#   Suez Canal blocked (Ever Given): max CAR = 14.13%, min CAR = -1.38%
#   Hormuz tanker attacks (escalation): max CAR = 15.62%, min CAR = -5.82%
#
# Adani Ports & SEZ:
#   Strait of Hormuz Blockade (hypothetical): max CAR = 23.77%, min CAR = -1.65%
#   Red Sea Houthi attacks (start): max CAR = 23.21%, min CAR = -2.76%
#   Suez Canal blocked (Ever Given): max CAR = 28.08%, min CAR = 1.80%
#   Hormuz tanker attacks (escalation): max CAR = 6.68%, min CAR = -2.19%
#   Maersk Tigris seizure: max CAR = 15.21%, min CAR = -1.29%
#   U.S.–Iranian Naval Dispute: max CAR = 25.25%, min CAR = 0.29%
#
# Aegis Logistics:
#   Strait of Hormuz Blockade (hypothetical): max CAR = 13.04%, min CAR = -5.65%
#
# Gujarat Pipavav Port:
#   Strait of Hormuz Blockade (hypothetical): max CAR = -1.60%, min CAR = -6.81%
#   Red Sea Houthi attacks (start): max CAR = 18.72%, min CAR = -0.22%
#   Suez Canal blocked (Ever Given): max CAR = 13.82%, min CAR = 1.99%
#   Hormuz tanker attacks (escalation): max CAR = -1.32%, min CAR = -21.69%
#   Maersk Tigris seizure: max CAR = 5.30%, min CAR = -10.09%
#   U.S.–Iranian Naval Dispute: max CAR = 4.13%, min CAR = -10.20%
#
# Shipping Corporation of India:
#   Strait of Hormuz Blockade (hypothetical): max CAR = 32.05%, min CAR = -8.24%
#   Red Sea Houthi attacks (start): max CAR = 8.38%, min CAR = -8.81%
#   Suez Canal blocked (Ever Given): max CAR = 31.01%, min CAR = -1.93%
#   Hormuz tanker attacks (escalation): max CAR = 1.01%, min CAR = -20.10%
#   Maersk Tigris seizure: max CAR = 25.62%, min CAR = 1.67%
#   U.S.–Iranian Naval Dispute: max CAR = 9.01%, min CAR = -17.67%
#
# Great Eastern Shipping:
#   Strait of Hormuz Blockade (hypothetical): max CAR = 6.34%, min CAR = -11.25%
#   Red Sea Houthi attacks (start): max CAR = 15.23%, min CAR = -8.71%
#   Suez Canal blocked (Ever Given): max CAR = 23.86%, min CAR = 3.30%
#   Hormuz tanker attacks (escalation): max CAR = 6.31%, min CAR = -15.18%
#   Maersk Tigris seizure: max CAR = 9.01%, min CAR = -2.75%
#   U.S.–Iranian Naval Dispute: max CAR = 4.54%, min CAR = -11.18%
#
# Gateway Distriparks:
#   Strait of Hormuz Blockade (hypothetical): max CAR = 6.57%, min CAR = -8.41%
#   Red Sea Houthi attacks (start): max CAR = 19.83%, min CAR = -1.20%
#
# Delhivery:
#   Strait of Hormuz Blockade (hypothetical): max CAR = 15.64%, min CAR = -1.23%
#   Red Sea Houthi attacks (start): max CAR = -2.13%, min CAR = -25.79%
#
# JSW Infra:
#   Strait of Hormuz Blockade (hypothetical): max CAR = 10.55%, min CAR = -7.47%
#   Red Sea Houthi attacks (start): max CAR = 26.47%, min CAR = -0.35%
#
# Blue Dart Express:
#   Strait of Hormuz Blockade (hypothetical): max CAR = 4.90%, min CAR = -6.59%
#   Red Sea Houthi attacks (start): max CAR = 4.18%, min CAR = -2.83%
#   Suez Canal blocked (Ever Given): max CAR = 20.02%, min CAR = -2.67%
#   Hormuz tanker attacks (escalation): max CAR = -1.72%, min CAR = -31.64%
#   Maersk Tigris seizure: max CAR = 3.33%, min CAR = -17.94%
#   U.S.–Iranian Naval Dispute: max CAR = 17.59%, min CAR = -0.91%
#
# TCI Express:
#   Strait of Hormuz Blockade (hypothetical): max CAR = 12.67%, min CAR = -3.43%
#   Red Sea Houthi attacks (start): max CAR = 4.69%, min CAR = -10.43%
#   Suez Canal blocked (Ever Given): max CAR = 1.56%, min CAR = -10.63%
#   Hormuz tanker attacks (escalation): max CAR = -1.80%, min CAR = -16.31%
#
# Allcargo Logistics:
#   Strait of Hormuz Blockade (hypothetical): max CAR = 21.69%, min CAR = -4.57%
#   Red Sea Houthi attacks (start): max CAR = 13.07%, min CAR = -4.74%
#   Suez Canal blocked (Ever Given): max CAR = 5.10%, min CAR = -2.50%
#   Hormuz tanker attacks (escalation): max CAR = -0.14%, min CAR = -12.47%
#   Maersk Tigris seizure: max CAR = 12.50%, min CAR = 3.22%
#   U.S.–Iranian Naval Dispute: max CAR = 2.92%, min CAR = -9.56%
#
# Container Corporation (CONCOR):
#   Strait of Hormuz Blockade (hypothetical): max CAR = 12.34%, min CAR = -4.70%
#   Red Sea Houthi attacks (start): max CAR = 14.33%, min CAR = -1.37%
#   Suez Canal blocked (Ever Given): max CAR = 7.67%, min CAR = -3.16%
#   Hormuz tanker attacks (escalation): max CAR = 3.83%, min CAR = -6.54%
#   Maersk Tigris seizure: max CAR = 15.18%, min CAR = -2.39%
#   U.S.–Iranian Naval Dispute: max CAR = 6.14%, min CAR = -7.30%
#
# Mahindra Logistics:
#   Strait of Hormuz Blockade (hypothetical): max CAR = 9.76%, min CAR = -11.42%
#   Red Sea Houthi attacks (start): max CAR = 3.21%, min CAR = -6.35%
#   Suez Canal blocked (Ever Given): max CAR = 22.36%, min CAR = -3.32%
#   Hormuz tanker attacks (escalation): max CAR = 8.46%, min CAR = -14.46%
#
# Asian Paints:
#   Strait of Hormuz Blockade (hypothetical): max CAR = 14.12%, min CAR = 0.29%
#   Red Sea Houthi attacks (start): max CAR = 2.49%, min CAR = -2.35%
#   Suez Canal blocked (Ever Given): max CAR = 12.52%, min CAR = -2.89%
#   Hormuz tanker attacks (escalation): max CAR = 1.25%, min CAR = -12.10%
#   Maersk Tigris seizure: max CAR = 6.71%, min CAR = 0.01%
#   U.S.–Iranian Naval Dispute: max CAR = 4.63%, min CAR = -4.43%
#
# Berger Paints:
#   Strait of Hormuz Blockade (hypothetical): max CAR = 18.08%, min CAR = -3.38%
#   Red Sea Houthi attacks (start): max CAR = 3.02%, min CAR = -7.89%
#   Suez Canal blocked (Ever Given): max CAR = 6.09%, min CAR = -5.49%
#   Hormuz tanker attacks (escalation): max CAR = 2.16%, min CAR = -10.67%
#   Maersk Tigris seizure: max CAR = 10.92%, min CAR = -0.05%
#   U.S.–Iranian Naval Dispute: max CAR = -0.34%, min CAR = -15.55%
#
# Kansai Nerolac Paints:
#   Strait of Hormuz Blockade (hypothetical): max CAR = 15.03%, min CAR = -12.07%
#   Red Sea Houthi attacks (start): max CAR = 0.46%, min CAR = -8.76%
#   Suez Canal blocked (Ever Given): max CAR = 8.75%, min CAR = -3.95%
#   Hormuz tanker attacks (escalation): max CAR = 3.95%, min CAR = -11.49%
#   Maersk Tigris seizure: max CAR = 8.47%, min CAR = -3.99%
#   U.S.–Iranian Naval Dispute: max CAR = 8.61%, min CAR = -4.88%
#
# JK Tyre & Industries:
#   Strait of Hormuz Blockade (hypothetical): max CAR = 0.96%, min CAR = -9.22%
#   Red Sea Houthi attacks (start): max CAR = 15.46%, min CAR = 1.74%
#   Suez Canal blocked (Ever Given): max CAR = 4.31%, min CAR = -11.29%
#   Hormuz tanker attacks (escalation): max CAR = 4.19%, min CAR = -14.32%
#   Maersk Tigris seizure: max CAR = 30.85%, min CAR = -0.12%
#   U.S.–Iranian Naval Dispute: max CAR = 9.17%, min CAR = -8.16%
#
# Apollo Tyres:
#   Strait of Hormuz Blockade (hypothetical): max CAR = 4.98%, min CAR = -4.94%
#   Red Sea Houthi attacks (start): max CAR = 10.45%, min CAR = -0.91%
#   Suez Canal blocked (Ever Given): max CAR = 7.90%, min CAR = -10.11%
#   Hormuz tanker attacks (escalation): max CAR = 3.01%, min CAR = -19.21%
#   Maersk Tigris seizure: max CAR = 14.65%, min CAR = 1.54%
#   U.S.–Iranian Naval Dispute: max CAR = 8.65%, min CAR = -11.32%
#
# CEAT:
#   Strait of Hormuz Blockade (hypothetical): max CAR = -2.28%, min CAR = -16.55%
#   Red Sea Houthi attacks (start): max CAR = 3.19%, min CAR = -5.75%
#   Suez Canal blocked (Ever Given): max CAR = 4.16%, min CAR = -10.14%
#   Hormuz tanker attacks (escalation): max CAR = 3.71%, min CAR = -13.00%
#   Maersk Tigris seizure: max CAR = 20.33%, min CAR = 0.32%
#   U.S.–Iranian Naval Dispute: max CAR = 17.40%, min CAR = -6.22%
#
# MRF:
#   Strait of Hormuz Blockade (hypothetical): max CAR = -0.17%, min CAR = -8.87%
#   Red Sea Houthi attacks (start): max CAR = 5.14%, min CAR = -5.13%
#   Suez Canal blocked (Ever Given): max CAR = 2.59%, min CAR = -7.61%
#   Hormuz tanker attacks (escalation): max CAR = 6.36%, min CAR = -8.11%
#   Maersk Tigris seizure: max CAR = 6.33%, min CAR = -5.55%
#   U.S.–Iranian Naval Dispute: max CAR = 7.41%, min CAR = -1.46%
#
# Balkrishna Industries:
#   Strait of Hormuz Blockade (hypothetical): max CAR = 0.85%, min CAR = -7.13%
#   Red Sea Houthi attacks (start): max CAR = 0.68%, min CAR = -14.72%
#   Suez Canal blocked (Ever Given): max CAR = 13.47%, min CAR = 1.17%
#   Hormuz tanker attacks (escalation): max CAR = 0.04%, min CAR = -26.63%
#   Maersk Tigris seizure: max CAR = 22.96%, min CAR = 1.52%
#   U.S.–Iranian Naval Dispute: max CAR = 3.82%, min CAR = -8.25%
#
# NTPC:
#   Strait of Hormuz Blockade (hypothetical): max CAR = 2.91%, min CAR = -5.94%
#   Red Sea Houthi attacks (start): max CAR = 16.98%, min CAR = -0.88%
#   Suez Canal blocked (Ever Given): max CAR = 8.21%, min CAR = -0.97%
#   Hormuz tanker attacks (escalation): max CAR = -0.02%, min CAR = -7.24%
#   Maersk Tigris seizure: max CAR = 7.29%, min CAR = -7.30%
#   U.S.–Iranian Naval Dispute: max CAR = 3.97%, min CAR = -3.23%
#
# Tata Power:
#   Strait of Hormuz Blockade (hypothetical): max CAR = 12.42%, min CAR = -3.39%
#   Red Sea Houthi attacks (start): max CAR = 26.38%, min CAR = -0.55%
#   Suez Canal blocked (Ever Given): max CAR = 21.79%, min CAR = 0.95%
#   Hormuz tanker attacks (escalation): max CAR = 3.13%, min CAR = -13.54%
#   Maersk Tigris seizure: max CAR = 3.88%, min CAR = -3.11%
#   U.S.–Iranian Naval Dispute: max CAR = 10.95%, min CAR = -4.69%
#
# Adani Power:
#   Strait of Hormuz Blockade (hypothetical): max CAR = 42.37%, min CAR = 0.36%
#   Red Sea Houthi attacks (start): max CAR = 37.04%, min CAR = 1.07%
#   Suez Canal blocked (Ever Given): max CAR = 67.57%, min CAR = -1.12%
#   Hormuz tanker attacks (escalation): max CAR = 14.63%, min CAR = -14.66%
#   Maersk Tigris seizure: max CAR = 2.89%, min CAR = -15.12%
#   U.S.–Iranian Naval Dispute: max CAR = 20.08%, min CAR = -9.34%
#
# Power Grid Corporation:
#   Strait of Hormuz Blockade (hypothetical): max CAR = 4.29%, min CAR = -4.65%
#   Red Sea Houthi attacks (start): max CAR = 8.75%, min CAR = -0.96%
#   Suez Canal blocked (Ever Given): max CAR = 3.02%, min CAR = -7.52%
#   Hormuz tanker attacks (escalation): max CAR = 0.74%, min CAR = -9.82%
#   Maersk Tigris seizure: max CAR = 4.18%, min CAR = -2.85%
#   U.S.–Iranian Naval Dispute: max CAR = 7.20%, min CAR = -2.88%
#
# JSW Energy:
#   Strait of Hormuz Blockade (hypothetical): max CAR = 10.32%, min CAR = -7.51%
#   Red Sea Houthi attacks (start): max CAR = 8.78%, min CAR = -6.56%
#   Suez Canal blocked (Ever Given): max CAR = 38.85%, min CAR = -1.76%
#   Hormuz tanker attacks (escalation): max CAR = 9.39%, min CAR = -4.43%
#   Maersk Tigris seizure: max CAR = 0.94%, min CAR = -9.90%
#   U.S.–Iranian Naval Dispute: max CAR = 18.33%, min CAR = -12.22%
#
# Torrent Power:
#   Strait of Hormuz Blockade (hypothetical): max CAR = 14.95%, min CAR = -8.41%
#   Red Sea Houthi attacks (start): max CAR = 24.42%, min CAR = -0.63%
#   Suez Canal blocked (Ever Given): max CAR = 17.82%, min CAR = 1.00%
#   Hormuz tanker attacks (escalation): max CAR = 4.82%, min CAR = -4.88%
#   Maersk Tigris seizure: max CAR = 5.61%, min CAR = -5.53%
#   U.S.–Iranian Naval Dispute: max CAR = 10.01%, min CAR = -2.83%
#
# Crompton Greaves:
#   Strait of Hormuz Blockade (hypothetical): max CAR = 16.13%, min CAR = -4.46%
#   Red Sea Houthi attacks (start): max CAR = 0.86%, min CAR = -9.21%
#   Suez Canal blocked (Ever Given): max CAR = 4.25%, min CAR = -5.72%
#   Hormuz tanker attacks (escalation): max CAR = 7.55%, min CAR = -1.45%
#
# BHEL:
#   Strait of Hormuz Blockade (hypothetical): max CAR = 40.93%, min CAR = -5.51%
#   Red Sea Houthi attacks (start): max CAR = 35.68%, min CAR = 1.05%
#   Suez Canal blocked (Ever Given): max CAR = 32.76%, min CAR = 0.19%
#   Hormuz tanker attacks (escalation): max CAR = 7.96%, min CAR = -13.38%
#   Maersk Tigris seizure: max CAR = 13.48%, min CAR = -5.10%
#   U.S.–Iranian Naval Dispute: max CAR = 2.39%, min CAR = -13.74%
#
# Kalpataru Power Transmission:
#   Strait of Hormuz Blockade (hypothetical): max CAR = 13.09%, min CAR = -4.97%
#   Red Sea Houthi attacks (start): max CAR = 26.26%, min CAR = 0.01%
#   Suez Canal blocked (Ever Given): max CAR = 43.72%, min CAR = 0.73%
#   Hormuz tanker attacks (escalation): max CAR = 8.81%, min CAR = -9.71%
#
# Solex Energy:
#   Strait of Hormuz Blockade (hypothetical): max CAR = 33.20%, min CAR = -9.69%
#   Red Sea Houthi attacks (start): max CAR = -0.70%, min CAR = -42.95%
#   Suez Canal blocked (Ever Given): max CAR = 60.94%, min CAR = 4.19%
#   Hormuz tanker attacks (escalation): max CAR = -0.86%, min CAR = -17.80%
#
# KPI Green Energy:
#   Strait of Hormuz Blockade (hypothetical): max CAR = 19.85%, min CAR = -5.49%
#   Red Sea Houthi attacks (start): max CAR = 48.97%, min CAR = 0.59%
#
# Servotech Renewable Power:
#   Strait of Hormuz Blockade (hypothetical): max CAR = 32.33%, min CAR = -6.78%
#   Red Sea Houthi attacks (start): max CAR = 0.47%, min CAR = -18.23%
#   Suez Canal blocked (Ever Given): max CAR = 11.63%, min CAR = 1.56%
#   Hormuz tanker attacks (escalation): max CAR = 17.17%, min CAR = -23.60%
#
# Inox Wind:
#   Strait of Hormuz Blockade (hypothetical): max CAR = 23.60%, min CAR = -6.41%
#   Red Sea Houthi attacks (start): max CAR = 74.11%, min CAR = -1.99%
#   Suez Canal blocked (Ever Given): max CAR = 33.79%, min CAR = 1.95%
#   Hormuz tanker attacks (escalation): max CAR = 5.34%, min CAR = -14.27%
#   Maersk Tigris seizure: max CAR = 11.50%, min CAR = -2.49%
#
# Suzlon Energy:
#   Strait of Hormuz Blockade (hypothetical): max CAR = 29.61%, min CAR = -2.52%
#   Red Sea Houthi attacks (start): max CAR = 29.65%, min CAR = 2.76%
#   Suez Canal blocked (Ever Given): max CAR = 14.41%, min CAR = -9.83%
#   Hormuz tanker attacks (escalation): max CAR = 12.23%, min CAR = -16.24%
#   Maersk Tigris seizure: max CAR = 6.07%, min CAR = -13.42%
#   U.S.–Iranian Naval Dispute: max CAR = 13.56%, min CAR = -24.49%
#
# IREDA:
#   Strait of Hormuz Blockade (hypothetical): max CAR = 16.66%, min CAR = -1.12%
#   Red Sea Houthi attacks (start): max CAR = 69.53%, min CAR = 1.74%
#
# Adani Green Energy:
#   Strait of Hormuz Blockade (hypothetical): max CAR = 47.91%, min CAR = -1.23%
#   Red Sea Houthi attacks (start): max CAR = 52.87%, min CAR = -3.32%
#   Suez Canal blocked (Ever Given): max CAR = 18.07%, min CAR = -2.82%
#   Hormuz tanker attacks (escalation): max CAR = 23.97%, min CAR = 0.58%
#
# Websol Energy System:
#   Strait of Hormuz Blockade (hypothetical): max CAR = 82.56%, min CAR = -3.76%
#   Red Sea Houthi attacks (start): max CAR = 32.09%, min CAR = -1.17%
#   Suez Canal blocked (Ever Given): max CAR = 27.80%, min CAR = 6.94%
#   Hormuz tanker attacks (escalation): max CAR = 4.10%, min CAR = -29.91%
#   Maersk Tigris seizure: max CAR = 25.84%, min CAR = 1.97%
#   U.S.–Iranian Naval Dispute: max CAR = 36.20%, min CAR = -8.48%
#
# Tata Chemicals:
#   Strait of Hormuz Blockade (hypothetical): max CAR = 16.80%, min CAR = -10.02%
#   Red Sea Houthi attacks (start): max CAR = 1.97%, min CAR = -7.08%
#   Suez Canal blocked (Ever Given): max CAR = 30.07%, min CAR = 5.04%
#   Hormuz tanker attacks (escalation): max CAR = 7.74%, min CAR = -6.45%
#   Maersk Tigris seizure: max CAR = 8.23%, min CAR = -1.25%
#   U.S.–Iranian Naval Dispute: max CAR = 2.59%, min CAR = -11.26%
#
# Deepak Nitrite:
#   Strait of Hormuz Blockade (hypothetical): max CAR = 24.20%, min CAR = -8.10%
#   Red Sea Houthi attacks (start): max CAR = 10.81%, min CAR = -0.87%
#   Suez Canal blocked (Ever Given): max CAR = 31.25%, min CAR = 0.93%
#   Hormuz tanker attacks (escalation): max CAR = 12.02%, min CAR = -7.06%
#   Maersk Tigris seizure: max CAR = 12.63%, min CAR = -0.82%
#   U.S.–Iranian Naval Dispute: max CAR = 9.71%, min CAR = -13.87%
#
# SRF Limited:
#   Strait of Hormuz Blockade (hypothetical): max CAR = 6.51%, min CAR = -9.42%
#   Red Sea Houthi attacks (start): max CAR = 5.16%, min CAR = -2.44%
#   Suez Canal blocked (Ever Given): max CAR = 16.96%, min CAR = -2.70%
#   Hormuz tanker attacks (escalation): max CAR = 18.26%, min CAR = -4.55%
#   Maersk Tigris seizure: max CAR = 19.19%, min CAR = 2.56%
#   U.S.–Iranian Naval Dispute: max CAR = -1.93%, min CAR = -20.14%
#
# Atul Ltd:
#   Strait of Hormuz Blockade (hypothetical): max CAR = 9.68%, min CAR = -1.36%
#   Red Sea Houthi attacks (start): max CAR = 5.66%, min CAR = -1.36%
#   Suez Canal blocked (Ever Given): max CAR = 21.33%, min CAR = -0.75%
#   Hormuz tanker attacks (escalation): max CAR = 10.72%, min CAR = -4.57%
#   Maersk Tigris seizure: max CAR = 10.09%, min CAR = -4.38%
#   U.S.–Iranian Naval Dispute: max CAR = 2.72%, min CAR = -21.80%
#
# Aarti Industries:
#   Strait of Hormuz Blockade (hypothetical): max CAR = 12.80%, min CAR = -7.50%
#   Red Sea Houthi attacks (start): max CAR = 23.95%, min CAR = -0.99%
#   Suez Canal blocked (Ever Given): max CAR = 23.91%, min CAR = 3.19%
#   Hormuz tanker attacks (escalation): max CAR = 15.98%, min CAR = -1.01%
#   Maersk Tigris seizure: max CAR = 9.42%, min CAR = -4.17%
#   U.S.–Iranian Naval Dispute: max CAR = 10.02%, min CAR = -4.43%
#
# Linde India:
#   Strait of Hormuz Blockade (hypothetical): max CAR = 7.39%, min CAR = -4.92%
#   Red Sea Houthi attacks (start): max CAR = 2.57%, min CAR = -19.61%
#   Suez Canal blocked (Ever Given): max CAR = 38.80%, min CAR = -0.27%
#   Hormuz tanker attacks (escalation): max CAR = 18.56%, min CAR = -5.16%
#   Maersk Tigris seizure: max CAR = 5.53%, min CAR = -4.47%
#   U.S.–Iranian Naval Dispute: max CAR = 11.61%, min CAR = -1.80%
#
# Vinati Organics:
#   Strait of Hormuz Blockade (hypothetical): max CAR = 4.28%, min CAR = -14.43%
#   Red Sea Houthi attacks (start): max CAR = 0.34%, min CAR = -12.71%
#   Suez Canal blocked (Ever Given): max CAR = 19.63%, min CAR = -1.23%
#   Hormuz tanker attacks (escalation): max CAR = 25.83%, min CAR = 2.09%
#   Maersk Tigris seizure: max CAR = 19.75%, min CAR = 0.38%
#   U.S.–Iranian Naval Dispute: max CAR = 5.77%, min CAR = -4.76%
#
# Navin Fluorine International:
#   Strait of Hormuz Blockade (hypothetical): max CAR = 12.50%, min CAR = -4.27%
#   Red Sea Houthi attacks (start): max CAR = 4.85%, min CAR = -2.02%
#   Suez Canal blocked (Ever Given): max CAR = 30.86%, min CAR = -0.86%
#   Hormuz tanker attacks (escalation): max CAR = 4.95%, min CAR = -9.08%
#   Maersk Tigris seizure: max CAR = 10.92%, min CAR = -2.79%
#   U.S.–Iranian Naval Dispute: max CAR = 0.98%, min CAR = -16.81%
#
# Maruti Suzuki:
#   Strait of Hormuz Blockade (hypothetical): max CAR = 3.91%, min CAR = -2.14%
#   Red Sea Houthi attacks (start): max CAR = -1.11%, min CAR = -14.51%
#   Suez Canal blocked (Ever Given): max CAR = -0.02%, min CAR = -7.27%
#   Hormuz tanker attacks (escalation): max CAR = 10.70%, min CAR = -0.23%
#   Maersk Tigris seizure: max CAR = 6.16%, min CAR = -5.59%
#   U.S.–Iranian Naval Dispute: max CAR = 17.79%, min CAR = -0.65%
#
# Mahindra & Mahindra:
#   Strait of Hormuz Blockade (hypothetical): max CAR = 8.58%, min CAR = -1.24%
#   Red Sea Houthi attacks (start): max CAR = 7.05%, min CAR = -0.25%
#   Suez Canal blocked (Ever Given): max CAR = -0.71%, min CAR = -10.60%
#   Hormuz tanker attacks (escalation): max CAR = 3.06%, min CAR = -5.22%
#   Maersk Tigris seizure: max CAR = 9.59%, min CAR = -1.84%
#   U.S.–Iranian Naval Dispute: max CAR = 1.25%, min CAR = -11.99%
#
# Bajaj Auto:
#   Strait of Hormuz Blockade (hypothetical): max CAR = 14.15%, min CAR = -1.07%
#   Red Sea Houthi attacks (start): max CAR = 11.88%, min CAR = -0.34%
#   Suez Canal blocked (Ever Given): max CAR = 1.30%, min CAR = -9.56%
#   Hormuz tanker attacks (escalation): max CAR = 4.64%, min CAR = -4.50%
#   Maersk Tigris seizure: max CAR = 15.63%, min CAR = -2.80%
#   U.S.–Iranian Naval Dispute: max CAR = 3.03%, min CAR = -9.75%
#
# Hero MotoCorp:
#   Strait of Hormuz Blockade (hypothetical): max CAR = 0.70%, min CAR = -8.95%
#   Red Sea Houthi attacks (start): max CAR = 17.39%, min CAR = -1.46%
#   Suez Canal blocked (Ever Given): max CAR = 3.16%, min CAR = -14.94%
#   Hormuz tanker attacks (escalation): max CAR = 9.31%, min CAR = -1.91%
#   Maersk Tigris seizure: max CAR = 5.42%, min CAR = -9.55%
#   U.S.–Iranian Naval Dispute: max CAR = -1.21%, min CAR = -18.99%
#
# Eicher Motors:
#   Strait of Hormuz Blockade (hypothetical): max CAR = 5.04%, min CAR = -3.00%
#   Red Sea Houthi attacks (start): max CAR = 16.23%, min CAR = 0.07%
#   Suez Canal blocked (Ever Given): max CAR = 5.95%, min CAR = -5.81%
#   Hormuz tanker attacks (escalation): max CAR = 2.30%, min CAR = -7.31%
#   Maersk Tigris seizure: max CAR = 23.18%, min CAR = -7.10%
#   U.S.–Iranian Naval Dispute: max CAR = -0.72%, min CAR = -7.48%
#
# TVS Motor Company:
#   Strait of Hormuz Blockade (hypothetical): max CAR = 10.45%, min CAR = -0.80%
#   Red Sea Houthi attacks (start): max CAR = 15.18%, min CAR = -1.58%
#   Suez Canal blocked (Ever Given): max CAR = 4.67%, min CAR = -8.28%
#   Hormuz tanker attacks (escalation): max CAR = 9.11%, min CAR = -0.97%
#   Maersk Tigris seizure: max CAR = -3.89%, min CAR = -19.33%
#   U.S.–Iranian Naval Dispute: max CAR = 0.05%, min CAR = -10.65%
#
# Ashok Leyland:
#   Strait of Hormuz Blockade (hypothetical): max CAR = -0.40%, min CAR = -13.86%
#   Red Sea Houthi attacks (start): max CAR = 3.60%, min CAR = -9.53%
#   Suez Canal blocked (Ever Given): max CAR = 7.60%, min CAR = -6.94%
#   Hormuz tanker attacks (escalation): max CAR = 7.24%, min CAR = -3.66%
#   Maersk Tigris seizure: max CAR = 8.97%, min CAR = -2.76%
#   U.S.–Iranian Naval Dispute: max CAR = 9.38%, min CAR = -11.11%
#
# Force Motors:
#   Strait of Hormuz Blockade (hypothetical): max CAR = 4.73%, min CAR = -12.38%
#   Red Sea Houthi attacks (start): max CAR = 0.47%, min CAR = -9.35%
#   Suez Canal blocked (Ever Given): max CAR = 1.06%, min CAR = -17.42%
#
# Tata Steel:
#   Strait of Hormuz Blockade (hypothetical): max CAR = 10.57%, min CAR = -3.08%
#   Red Sea Houthi attacks (start): max CAR = 3.41%, min CAR = -2.00%
#   Suez Canal blocked (Ever Given): max CAR = 37.23%, min CAR = 4.11%
#   Hormuz tanker attacks (escalation): max CAR = 8.66%, min CAR = -8.42%
#   Maersk Tigris seizure: max CAR = 21.64%, min CAR = -2.75%
#   U.S.–Iranian Naval Dispute: max CAR = 5.23%, min CAR = -14.24%
#
# JSW Steel:
#   Strait of Hormuz Blockade (hypothetical): max CAR = 8.05%, min CAR = -2.48%
#   Red Sea Houthi attacks (start): max CAR = 5.78%, min CAR = -1.14%
#   Suez Canal blocked (Ever Given): max CAR = 53.72%, min CAR = 1.05%
#   Hormuz tanker attacks (escalation): max CAR = 5.99%, min CAR = -8.09%
#   Maersk Tigris seizure: max CAR = 8.65%, min CAR = -4.99%
#   U.S.–Iranian Naval Dispute: max CAR = 1.49%, min CAR = -18.89%
#
# Hindalco Industries:
#   Strait of Hormuz Blockade (hypothetical): max CAR = 9.17%, min CAR = -9.31%
#   Red Sea Houthi attacks (start): max CAR = 16.50%, min CAR = 1.17%
#   Suez Canal blocked (Ever Given): max CAR = 22.06%, min CAR = 4.67%
#   Hormuz tanker attacks (escalation): max CAR = 6.46%, min CAR = -5.50%
#   Maersk Tigris seizure: max CAR = 7.47%, min CAR = -5.52%
#   U.S.–Iranian Naval Dispute: max CAR = 13.87%, min CAR = -5.76%
#
# SAIL:
#   Strait of Hormuz Blockade (hypothetical): max CAR = 18.94%, min CAR = -4.96%
#   Red Sea Houthi attacks (start): max CAR = 27.12%, min CAR = -0.66%
#   Suez Canal blocked (Ever Given): max CAR = 43.04%, min CAR = 4.34%
#   Hormuz tanker attacks (escalation): max CAR = 15.28%, min CAR = -4.61%
#   Maersk Tigris seizure: max CAR = 10.25%, min CAR = -3.97%
#   U.S.–Iranian Naval Dispute: max CAR = 15.58%, min CAR = -7.08%
#
# Jindal Steel & Power:
#   Strait of Hormuz Blockade (hypothetical): max CAR = 2.99%, min CAR = -6.62%
#   Red Sea Houthi attacks (start): max CAR = 8.09%, min CAR = -7.22%
#   Suez Canal blocked (Ever Given): max CAR = 37.27%, min CAR = -3.17%
#   Hormuz tanker attacks (escalation): max CAR = 12.66%, min CAR = -7.49%
#   Maersk Tigris seizure: max CAR = 1.63%, min CAR = -26.81%
#   U.S.–Iranian Naval Dispute: max CAR = 5.23%, min CAR = -8.97%
#
# --------------------------------------------------------------------------------
# Computing correlation matrices for each event...
# Analysis complete.
